# %% [markdown]
# # Fetch the data

# %%
import os
import glob
import pandas as pd

raw_data_path = "/content/drive/My Drive/ba/ba_data"
raw_data_folders = next(os.walk(raw_data_path))[1]
raw_data_files_by_folder = {raw_data_folder.split("@")[0]: glob.glob(f"{raw_data_path}/{raw_data_folder}/*") for raw_data_folder in raw_data_folders}
df_by_file_by_folder = { folder: { file_path.split("/")[-1].split(".csv")[0]: pd.read_csv(file_path) for file_path in file_paths} for folder, file_paths in raw_data_files_by_folder.items()}
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.

# %% [markdown]
# # Clean the data & check for integrity

# %%
def normalize_columns(df):
    # for column in df.drop(["dt"], axis=1).columns.tolist():
    df[df.drop(["dt"], axis=1).columns.tolist()] = (df[df.drop(["dt"], axis=1).columns.tolist()] - df[df.drop(["dt"], axis=1).columns.tolist()].mean()) / df[df.drop(["dt"], axis=1).columns.tolist()].std()
    # to ms
    # df["dt"] = df["dt"].apply(lambda x: int(x / 1_000_000))

    return df

def shift_dt_to_zero(folder):
    min_dt = df_by_file_by_folder[folder]["bno"]["dt"][100]

    for _, df in df_by_file_by_folder[folder].items():
        local_min_dt = df["dt"].min()
        min_dt = min(local_min_dt, min_dt)

    for filename, df in df_by_file_by_folder[folder].items():
        df_by_file_by_folder[folder][filename]["dt"] = df_by_file_by_folder[folder][filename]["dt"].apply(lambda x: x - min_dt)



for folder, df_by_files in df_by_file_by_folder.items():
    for filename, df in df_by_files.items():

        # Ensure all are valid floats
        df_by_files[filename] = df.apply(pd.to_numeric, errors='coerce')

        # Drop N/A
        df_by_files[filename] = df.dropna(axis=0, how="any")

        # Normalize
        # df_by_files[filename] = normalize_columns(df_by_files[filename])
    
    # Shift dt to 0
    shift_dt_to_zero(folder)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # For every folder plot its dfs in a single figure

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

def plot_folder(folder_name):
    fig = make_subplots()
    dfs_by_file = df_by_file_by_folder[folder_name]

    for filename, df in dfs_by_file.items():

        for column in df.drop(["dt"], axis=1).columns.tolist():

            trace = go.Scatter(
            x=df["dt"],
            y=df[column],
            name=f"{filename}:{column}",
            )
            
            fig.add_trace(trace)

    fig.update_layout(title_text=folder_name)
    fig.write_html(f"plots/{folder_name}-plot.html", auto_open=True)

# %%
# for folder, _ in df_by_file_by_folder.items():
#     plot_folder(folder)

# plot_folder("amelbenn")

# %% [markdown]
# # Interpolate the data

# %%
# labels & meta

labels = {
    "nasekoch": {
        "timeranges": [
            [119231, 121265],
            [123114, 125234],
            [127166, 129195],

            [131416, 135005],
            [137112, 140208],
            [141967, 145829],

            [213176, 215265],
            [217916, 220249],
            [222218, 224873],

            [226591, 230245],
            [232566, 235830],
            [237661, 240948],

            [254020, 256262],
            [258132, 260878],
            [262545, 264712],

            [266796, 270863],
            [273278, 277297],
            [278471, 282116],

            [286196, 288841],
            [290504, 293305],
            [295206, 297897],

            [299069, 303018],
            [304074, 308569],
            [309612, 314484],


            [316669, 319023],
            [320487, 322442],
            [324795, 327586],

            [329284, 333153],
            [334747, 338843],
            [340063, 344857],

            [346152, 349589],
            [350828, 354071],
            [355596, 358868],

            [360244, 363559],
            [364294, 367172],
            [368247, 371181],

            [372564, 377512],
            [378799, 382830],
            [383872, 387873],

            [409311, 421889],
            [423702, 430391],
            [432341, 438502],
            [439865, 446016],
            [447409, 452958],
            [455100, 461470],
            [462625, 468570],
            [469797, 476224],
            [477219, 482523],

            [488079, 493301],
            [495953, 500832],
            [502757, 507027],
            [508999, 514103],
            [515823, 521853],
            [530799, 536112],
            [537185, 543296],
            [544395, 549405],
            [551660, 556469],
            [558195, 563827],
        ],
        "device_click": 100343,
        "audio_click": 69103
    },

    "luormiau": {
        "timeranges": [
            [196579, 199536],
            [200812, 205850],
            [209850, 212457],

            [213857, 216205],
            [217876, 220164],

            [223528, 226715],
            [228685, 231941],
            [233586, 236738],

            [240941, 242987],
            [244759, 247407],
            [248819, 250573],

            [254170, 257298],
            [259544, 263058],
            [265666, 268381],

            [276129, 278100],
            [279762, 282116],
            [283817, 286157],

            [287826, 289879],
            [292133, 295187],
            [296909, 300406],
            [302109, 306252],

            [310601, 312638],
            [314621, 316777],
            [318390, 320371],

            [323878, 326618],
            [328468, 331954],
            [333249, 336584],

            [347300, 349949],
            [352186, 354417],
            [355726, 358012],

            [360465, 363767],
            [364941, 367900],
            [369325, 372565],

            [376743, 378867],
            [380871, 382932],
            [384763, 386805],

            [389744, 392896],
            [394752, 398133],
            [399712, 402599],

            [436746, 438720],
            [441068, 443564],
            [445372, 447326],

            [449504, 452504],
            [454541, 457952],
            [459532, 462553],

            [493863, 497936],
            [499855, 504414],
            [505920, 510301],

            [511866, 517356],
            [519535, 524903],
            [526196, 530708],

            [531953, 536973],
            [539118, 544965],
            [546397, 552252],
            [553308, 558253],

            [568278, 573629],
            [575747, 581207],
            [582965, 588258],

            [589835, 593957],
            [595475, 599705],
            [601162, 606757],

            [607976, 613243],
            [614104, 619561],
            [620908, 626441],
            [628571, 634000]
        ],
        "device_click": 174048,
        "audio_click": 144660
    },

    "liiukoim": {
        "timeranges": [
            [107030, 110370],
            [112986, 115653],
            [117908, 119636],
            [123068, 127507],
            [129619, 133762],
            [134844, 139136],
            [141210, 143789],
            [145047, 148261],
            [149759, 152840],
            [154672, 157160],
            [176183, 179421],
            [181197, 184010],
            [185766, 188575],
            [190280, 194438],
            [196331, 200365],
            [202591, 206026],
            [208950, 211322],
            [212787, 215822],
            [217269, 219841],
            [221277, 224771],
            [233741, 238032],
            [369310, 402679],
            [406539, 410754],
            [412248, 419420],
            [420954, 428739],
            [430332, 437296],
            [439008, 445947],
            [447332, 454463],
            [457544, 462726],
            [464022, 470321],
            [471440, 477583],
            [486186, 490836],
            [493653, 498959],
            [505525, 511856],
            [513829, 520347],
            [522222, 527527],
            [530032, 535876],
            [537978, 543282],
            [546228, 551457],
            [552791, 557988],
        ],
        "device_click": 99098,
        "audio_click": 91138
    },

    "siinkoau": {
        "timeranges": [
            [100040, 102311],
            [103857, 106188],
            [107402, 109650],
            [112489, 115713],
            [117066, 121164],
            [122216, 126113],
            [129211, 131156],
            [132674, 135184],
            [136763, 139563],
            [142110, 145382],
            [147176, 150602],
            [152673, 156809],
            [160276, 162683],
            [164239, 162072],
            [168148, 171213],
            [173560, 177328],
            [178917, 183054],
            [184769, 189563],
            [192254, 196411],
            [196398, 201121],
            [202747, 205314],
            [207814, 212512],
            [214066, 218549],
            [220463, 225480],
            [232510, 235078],
            [237088, 239995],
            [241798, 245049],
            [246759, 250412],
            [252176, 255659],
            [257206, 261395],
            [296341, 298627],
            [300474, 302540],
            [304709, 306730],
            [309691, 313231],
            [315049, 318720],
            [320201, 325087],
            [328654, 331225],
            [332666, 335748],
            [336748, 339787],
            [341876, 345534],
            [347253, 351618],
            [353010, 357956],
            [373136, 378146],
            [379977, 386230],
            [387658, 393549],
            [395895, 402509],
            [404211, 410578],
            [412685, 417536],
            [419911, 425730],
            [427371, 433726],
            [435692, 440328],
            [443752, 450110],
            [458457, 463931],
            [468005, 473094],
            [484006, 488541],
            [492114, 497952],
            [500128, 504655],
            [506614, 511980],
            [513543, 519866],
            [522097, 527612],
            [529265, 535202]
        ],
        "device_click": 90716,
        "audio_click": 95190
    },

    "kausenel": {
        "timeranges": [
            [152242, 154294],
            [158026, 160043],
            [162660, 165570],
            [168044, 171930],
            [175510, 179270],
            [183036, 186589],
            [191690, 193919],
            [198890, 201076],
            [202056, 205296],
            [208746, 211583],
            [214551, 217643],
            [220671, 223882],
            [230767, 234067],
            [236084, 238777],
            [239939, 242015],
            [243285, 245865],
            [247036, 249737],
            [251356, 254046],
            [258807, 261351],
            [263072, 265479],
            [267373, 269884],
            [272086, 274515],
            [276240, 279205],
            [281128, 284025],
            [286428, 289306],
            [321364, 323787],
            [326524, 329010],
            [331003, 333355],
            [335858, 339234],
            [340617, 344386],
            [346795, 349944],
            [353253, 356772],
            [359031, 361787],
            [363412, 365070],
            [368181, 371775],
            [373216, 376226],
            [378655, 381901],
            [403073, 405320],
            [407275, 409149],
            [411528, 413216],
            [416534, 419820],
            [420869, 424204],
            [426113, 428538],
            [437976, 441576],
            [443242, 445592],
            [447826, 449086],
            [452568, 455342],
            [458091, 461328],
            [463867, 466866],
            [522705, 527062],
            [530715, 535165],
            [537592, 542315],
            [544443, 549801],
            [552870, 557765],
            [561415, 566938],
            [569426, 574491],
            [576778, 581273],
            [582814, 589335],
            [592217, 596369],
            [597918, 603781],
            [609501, 613970],
            [617760, 623674],
            [627596, 632251],
            [636631, 642228],
            [645557, 651327],
            [654652, 650580],
            [663168, 672061],
            [673634, 679300],
            [681339, 689152],
            [692005, 697998],
            [701638, 707461],
        ],
        "device_click": 132852,
        "audio_click": 174196
    },

    "aneimiau": {
        "timeranges": [
            [121553, 126360],
            [125220, 126375],
            [129456, 131212],
            [135957, 137919],
            [139508, 142223],
            [143712, 146034],
            [148722, 152042],
            [153479, 156577],
            [158202, 161022],
            [165380, 168306],
            [170164, 172449],
            [174197, 176618],
            [178983, 181601],
            [183535, 185493],
            [187428, 190214],
            [194604, 196375],
            [198381, 201281],
            [203646, 205796],
            [208608, 211733],
            [212999, 216569],
            [218885, 221975],
            [233062, 235404],
            [237611, 239581],
            [241436, 243568],
            [246659, 249502],
            [251097, 253736],
            [255787, 258415],
            [261058, 263271],
            [264482, 266770],
            [268434, 270701],
            [272966, 275990],
            [277858, 281264],
            [283073, 286012],
            [288739, 291932],
            [293526, 295956],
            [297627, 299604],
            [300864, 303720],
            [305590, 309513],
            [310982, 314205],
            [318237, 321451],
            [323103, 325570],
            [327293, 329968],
            [331981, 335307],
            [336925, 340265],
            [341809, 345985],
            [365038, 368457],
            [370376, 373764],
            [375401, 379242],
            [380244, 383960],
            [385373, 388915],
            [390520, 393027],
            [394229, 397356],
            [398433, 401443],
            [402852, 405772],
            [407152, 409793],
            [417975, 421027],
            [422409, 427257],
            [428557, 432961],
            [434044, 438263],
            [439542, 443942],
            [445374, 449534],
            [450962, 454957],
            [457014, 461677],
            [463217, 467873],
            [469612, 473864],
        ],
        "device_click": 95202,
        "audio_click": 54602
    },

    "amelbenn": {
        "timeranges": [
            [227573, 229734],
            [232280, 234099],
            [236183, 237782],
            [242128, 244714],
            [246479, 249272],
            [250635, 252984],
            [254463, 256704],
            [259970, 261992],
            [263465, 265135],
            [266843, 268885],
            [270387, 271761],
            [274874, 276997],
            [278478, 280880],
            [282599, 284513],
            [289852, 292826],
            [294419, 297167],
            [298621, 301160],
            [334491, 337104],
            [338640, 340535],
            [342356, 344126],
            [346966, 349567],
            [351092, 353242],
            [355013, 357530],
            [378085, 380845],
            [382294, 384758],
            [386432, 388382],
            [390898, 393728],
            [395678, 397977],
            [399325, 402547],
            [404647, 407461],
            [408587, 411498],
            [412763, 415195],
            [418004, 421052],
            [422402, 425521],
            [426750, 430468],
            [470678, 472783],
            [474215, 476761],
            [478265, 480162],
            [482970, 485885],
            [487890, 490407],
            [492222, 494749],
            [579385, 586382],
            [591092, 598277],
            [601489, 610189],
            [615230, 621606],
            [625429, 631061],
            [635210, 639871],
            [642582, 648378],
            [651986, 657121],
            [661136, 667424],
            [669410, 677151],
            [725629, 731642],
            [735982, 741336],
            [744994, 750997],
            [753722, 760211],
            [762634, 768153],
            [771092, 776683],
            [780636, 785603],
            [789238, 793861],
        ],
        "device_click": 204838,
        "audio_click": 229397
    },

    "sviokoau": {
        "timeranges": [
            [240660, 242349],
            [245731, 247997],
            [249832, 252129],
            [257280, 260121],
            [262027, 266135],
            [267639, 271348],
            [272160, 274436],
            [276816, 278860],
            [280950, 282991],
            [286141, 288915],
            [292805, 295889],
            [297969, 301392],
            [305812, 308973],
            [310478, 313440],
            [315105, 317075],
            [320157, 324142],
            [325798, 328284],
            [331276, 334436],
            [337983, 340349],
            [342726, 345182],
            [347959, 350299],
            [352099, 354796],
            [357490, 361932],
            [363351, 365734],
            [366615, 368353],
            [369860, 371880],
            [372739, 375233],
            [388232, 389834],
            [393566, 397534],
            [399373, 402106],
            [405673, 407052],
            [421503, 423422],
            [425345, 427126],
            [428074, 430370],
            [567025, 573348],
            [576251, 581971],
            [583779, 587595],
            [591696, 595977],
            [599232, 604305],
            [606517, 611254],
            [614416, 618639],
            [622089, 626780],
            [628422, 633520],
            [645295, 649328],
            [651044, 654662],
            [658547, 662993],
            [668345, 672336],
            [674924, 680455],
            [682758, 689225],
            [691973, 697412],
            [699125, 703535],
            [715443, 720325]
        ],
        "device_click": 170614,
        "audio_click": None
    },

    "maipmiau": {
        "timeranges": [
            [120817, 122759],
            [125506, 127381],
            [130070, 131041],
            [134652, 136983],
            [139611, 142932],
            [144852, 146820],
            [151115, 153623],
            [155567, 157731],
            [159568, 161589],
            [163328, 166755],
            [169062, 172493],
            [175331, 179061],
            [182697, 184715],
            [186810, 189155],
            [190952, 193708],
            [195262, 199193],
            [200736, 204445],
            [206083, 209393],
            [213243, 216134],
            [218549, 221726],
            [223838, 226736],
            [228776, 233427],
            [235799, 238914],
            [242545, 246239],
            [262671, 265477],
            [267255, 269585],
            [272374, 274856],
            [277888, 281638],
            [283713, 287541],
            [290660, 294850],
            [298448, 301559],
            [303637, 307191],
            [309330, 312663],
            [314615, 318479],
            [320871, 326197],
            [328400, 332905],
            [335370, 338256],
            [340916, 343715],
            [345845, 349286],
            [351613, 356180],
            [358195, 363039],
            [364551, 369253],
            [373861, 376183],
            [378049, 381799],
            [384114, 386806],
            [388932, 392458],
            [394841, 398409],
            [401098, 405602],
            [431712, 436470],
            [438521, 443112],
            [448849, 454022],
            [455639, 459792],
            [463039, 469057],
            [470799, 475913],
            [478780, 482652],
            [486691, 491493],
            [494833, 499694],
            [517823, 522427],
            [524300, 529069],
            [538765, 543051],
            [546199, 550994],
            [555910, 560598],
            [562542, 567120],
            [568687, 571997],
            [574186, 582872],
            [586496, 590397],
            [591762, 596932],
        ],
        "device_click": 109393,
        "audio_click": 42167
    },

    "crhagach": {
        "timeranges": [
            [160784, 171798],
            [174415, 178904],
            [181343, 184106],
            [185996, 188855],
            [192392, 194517],
            [196791, 199849],
            [201438, 203751],
            [207047, 209896],
            [211756, 214567],
            [216838, 220030],
            [222921, 225076],
            [226593, 528862],
            [230270, 232704],
            [235105, 237548],
            [239285, 241587],
            [243090, 245555],
            [252290, 254641],
            [256002, 258918],
            [260359, 262578],
            [264537, 267380],
            [268855, 271599],
            [272957, 275941],
            [313245, 316397],
            [318069, 320595],
            [322342, 326016],
            [327976, 331450],
            [332542, 336060],
            [338558, 341866],
            [343123, 345369],
            [346744, 348602],
            [350822, 354045],
            [355672, 359119],
            [361199, 364625],
            [370146, 372019],
            [373068, 375762],
            [377071, 379309],
            [381348, 384990],
            [386507, 390045],
            [391243, 395114],
            [418823, 424373],
            [430310, 438323],
            [445128, 451495],
            [459615, 466233],
            [472768, 481371],
            [488208, 495283],
            [502608, 509754],
            [518445, 525109],
            [532836, 541816],
            [559980, 566472],
            [573353, 579792],
            [586689, 594294],
            [601513, 608326],
            [615584, 623138],
            [531438, 640013],
            [646306, 654944],
            [661756, 669343],
            [676974, 685005],
        ],
        "device_click": 135015,
        "audio_click": 132063
    },
}

# %%
from datetime import datetime

def resample_df(df, freq, cut_from, cut_to):
    df = df.set_index("dt")
    df.index = df.index.map(int)
    try:
        df.index = pd.to_datetime(df.index)
    except Exception as e:
        print(df.index, df, cut_from, cut_to)
        raise(e)

    old_index = df.index

    new_index = pd.date_range(0, old_index.max(), freq=freq)
    res = df.reindex(old_index.union(new_index)).interpolate(method="linear").reindex(new_index)
    res = res[(res.index >= datetime.utcfromtimestamp(cut_from/1_000.0)) & (res.index <= datetime.utcfromtimestamp(cut_to//1_000_000_000.0))]

    return res

# %%
# dfs = df_by_file_by_folder["amelbenn"]
# df = dfs["bno"]

# df = df.set_index("dt")
# df.index = pd.to_datetime(df.index)

# # 

# old_index = df.index

# new_index = pd.date_range(old_index.min(), old_index.max(), freq="4ms")
# res = df.reindex(old_index.union(new_index)).interpolate(method="linear").reindex(new_index)

FREQ = "10ms"
dfs_global_timestamp_minmax = {}

for folder, df_by_files in df_by_file_by_folder.items():
    dfs_global_timestamp_minmax[folder] = []
    for filename, df in df_by_files.items():
        dfs_global_timestamp_minmax[folder].append(df["dt"].iat[-1])
        
dfs_global_timestamp_minmax = {folder: min(max_ts) for folder, max_ts in dfs_global_timestamp_minmax.items()}

for folder, df_by_files in df_by_file_by_folder.items():
    for filename, df in df_by_files.items():
        df_by_files[filename] = resample_df(df, FREQ, labels[folder]["device_click"], dfs_global_timestamp_minmax[folder])

# %% [markdown]
# # Add all datasets to one big table & Label the data

# %%
data_to_remove_by_folder = {
    "amelbenn": [
        "temporalis_left"
    ],
    "aneimiau": [
        "temporalis_left"
    ],
    "kausenel": [
        "temporalis_right"
    ],
    "maipmiau": [
        "temporalis_left"
    ]
}

# %%
def is_bruxism(folder, row):
    for dt_range in labels[folder]["timeranges"]:
        if row.name >= datetime.utcfromtimestamp(dt_range[0] / 1_000.0) and row.name <= datetime.utcfromtimestamp(dt_range[1] / 1_000.0):
            return 1
    return 0

bigdfs_by_folder = {}

for folder, df_by_files in df_by_file_by_folder.items():
    start_ts = df_by_files["bno"].index[0]
    end_ts = df_by_files["bno"].index[-1]

    new_index = pd.date_range(start_ts, end_ts, freq=FREQ)
    big_df = pd.DataFrame(index=new_index, columns=["is_bruxism"])
    big_df = big_df.fillna(0)

    big_df["is_bruxism"] = big_df.apply(lambda x: is_bruxism(folder, x), axis=1)

    for filename, df in df_by_files.items():
        big_df = big_df.merge(right=df, left_index=True, right_index=True, how="left", suffixes=("", f"_2"))

    columns_to_drop = data_to_remove_by_folder.get(folder, None)
    if columns_to_drop is not None:
        for col in columns_to_drop:
            big_df.drop(col, inplace=True, axis=1)

    big_df = big_df.fillna(0)

    bigdfs_by_folder[folder] = big_df

# %%
bigdfs_by_folder["nasekoch"].columns
# bigdfs_by_folder["siinkoau"].columns
# Out:
# Index(['is_bruxism', 'acceleration_x', 'acceleration_y', 'acceleration_z',
#        'gyro_x', 'gyro_y', 'gyro_z', 'gsr', 'acceleration_x_2',
#        'acceleration_y_2', 'acceleration_z_2', 'gyro_x_2', 'gyro_y_2',
#        'gyro_z_2', 'x28_gyro_x', 'x28_gyro_y', 'x28_gyro_z',
#        'x28_acceleration_x', 'x28_acceleration_y', 'x28_acceleration_z',
#        'x28_quaternion_w', 'x28_quaternion_x', 'x28_quaternion_y',
#        'x28_quaternion_z', 'x29_gyro_x', 'x29_gyro_y', 'x29_gyro_z',
#        'x29_acceleration_x', 'x29_acceleration_y', 'x29_acceleration_z',
#        'x29_quaternion_w', 'x29_quaternion_x', 'x29_quaternion_y',
#        'x29_quaternion_z', 'masseter_left', 'masseter_right',
#        'temporalis_left', 'temporalis_right'],
#       dtype='object')

# %%
# fig = make_subplots()
# df = bigdfs_by_folder["nasekoch"]

# for column in df.columns.tolist():
#     trace = go.Scatter(
#     x=df.index,
#     y=df[column],
#     name=f"{column}",
#     )
    
#     fig.add_trace(trace)

# fig.update_layout(title_text="nasekoch")
# fig.write_html(f"debug-plot.html", auto_open=True)

# %%
from itertools import chain, combinations

def all_subsets(iterable):
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(1, len(s)+1))


df = bigdfs_by_folder["nasekoch"]
columns = df.drop(["is_bruxism"], axis=1).columns.tolist()

# columns

raw_features_types = {
    # "bno_gyro": ['x28_gyro_x', 'x28_gyro_y', 'x28_gyro_z', "x29_gyro_x", "x29_gyro_y", "x29_gyro_z"],
    # "bno_acc": ["x28_acceleration_x", "x28_acceleration_y", "x28_acceleration_z", "x29_acceleration_x", "x29_acceleration_y", "x29_acceleration_z"],
    "bno_quat": ["x28_quaternion_w", "x28_quaternion_x", "x28_quaternion_y", "x28_quaternion_z", "x29_quaternion_w", "x29_quaternion_x", "x29_quaternion_y", "x29_quaternion_z"],

    # "ble_gyro": ["gyro_x", "gyro_y", "gyro_z", "gyro_x_2", "gyro_y_2", "gyro_z_2"],
    # "ble_acc": ["acceleration_x", "acceleration_y", "acceleration_z", "acceleration_x_2", "acceleration_y_2", "acceleration_z_2"],

    # "gsr": ["gsr"],

    # "masseter": ["masseter_left", "masseter_right"],

    # "temporalis": ["temporalis_left", "temporalis_right"]
}

feature_types_subsets = list(all_subsets(raw_features_types.keys()))
feature_types_subsets.sort(key=len)

feature_types_subsets
# Out:
# [('bno_quat',)]

# %% [markdown]
# # Separate big dfs in windows

# %%
# print(list(bigdfs_by_folder["nasekoch"][0:5][["gyro_x", "gyro_y"]].to_numpy().flatten()))

# %%
# print(bigdfs_by_folder["nasekoch"][0:5][["gyro_x", "gyro_y"]])
# print(1 if (bigdfs_by_folder["nasekoch"][0:5][["is_bruxism"]].sum()) > (5/2) else 0)

# print(1 if bigdfs_by_folder["nasekoch"][0:100][["is_bruxism"]].sum()["is_bruxism"] > 100/2 else 0)

# %%
# bigdfs_by_folder["nasekoch"][:8]

# %%
# [(i - 1_600, i) for i in range(1_600, 10_000, 800)]

# %%
# for folder, df in bigdfs_by_folder.items():
#     print(folder, df["x28_gyro_x"].isnull())

# %%
# import time
# import numpy as np

# WINDOW_SIZE_MS = 1_600
# WINDOW_OVERLAP_PER = 0.5
# WINDOW_OVERLAP_MS = int(WINDOW_SIZE_MS * WINDOW_OVERLAP_PER)

# freq = int(FREQ.split("ms")[0])
# WINDOW_SIZE_INDEX = WINDOW_SIZE_MS // freq
# WINDOW_OVERLAP_INDEX = WINDOW_OVERLAP_MS // freq

# windows_with_labels__for_feature_set = {",".join(feature_set): {"data": [], "labels": []} for feature_set in feature_types_subsets}

# used_features_by_feature_set = {feature_set: [] for feature_set in windows_with_labels__for_feature_set.keys()}
# for feature_set in used_features_by_feature_set.keys():
#     for feature_type in feature_set.split(","):
#         used_features_by_feature_set[feature_set] += raw_features_types[feature_type]


# for folder, bigdf in bigdfs_by_folder.items():
#     start = time.time()

#     windows_ranges = [(i - WINDOW_SIZE_INDEX, i) for i in range(WINDOW_SIZE_INDEX, len(bigdf.index), WINDOW_OVERLAP_INDEX)]
#     labels = [1 if bigdf[index_range[0]:index_range[1]][["is_bruxism"]].sum()["is_bruxism"] >= WINDOW_SIZE_INDEX // 2 else 0 for index_range in windows_ranges]

#     for feature_set in windows_with_labels__for_feature_set.keys():
#         used_features = used_features_by_feature_set[feature_set]
#         try:
#             bigdf[used_features]
#         except:
#             print(f"{folder} does not have all of the {used_features} columns")
#             continue

#         windows_with_labels__for_feature_set[feature_set]["data"] += [bigdf[index_range[0]:index_range[1]][used_features].to_numpy().flatten() for index_range in windows_ranges]
#         windows_with_labels__for_feature_set[feature_set]["labels"] += labels

#     windows_with_labels__for_feature_set[feature_set]["data"] = np.asarray(windows_with_labels__for_feature_set[feature_set]["data"])
#     windows_with_labels__for_feature_set[feature_set]["labels"] = np.asarray(windows_with_labels__for_feature_set[feature_set]["labels"])
#     print(f"{folder} done in {time.time() - start}s")

# %%
# len(windows_with_labels__for_feature_set["bno_gyro"]["data"])
# len(windows_with_labels__for_feature_set["ble_gyro"]["data"])

# %%
import time
import numpy as np

WINDOW_SIZE_MS = 1_600
WINDOW_OVERLAP_PER = 0.5
WINDOW_OVERLAP_MS = int(WINDOW_SIZE_MS * WINDOW_OVERLAP_PER)

freq = int(FREQ.split("ms")[0])
WINDOW_SIZE_INDEX = WINDOW_SIZE_MS // freq
WINDOW_OVERLAP_INDEX = WINDOW_OVERLAP_MS // freq

windows_with_labels__for_feature_set = {",".join(feature_set): {"data": [], "labels": []} for feature_set in feature_types_subsets}

used_features_by_feature_set = {feature_set: [] for feature_set in windows_with_labels__for_feature_set.keys()}
for feature_set in used_features_by_feature_set.keys():
    for feature_type in feature_set.split(","):
        used_features_by_feature_set[feature_set] += raw_features_types[feature_type]

for feature_set in windows_with_labels__for_feature_set.keys():
    used_features = used_features_by_feature_set[feature_set]

    for folder, bigdf in bigdfs_by_folder.items():
        try:
            bigdf[used_features]
        except:
            print(f"{folder} does not have all of the {used_features} columns")
            continue

        windows_ranges = [(i - WINDOW_SIZE_INDEX, i) for i in range(WINDOW_SIZE_INDEX, len(bigdf.index), WINDOW_OVERLAP_INDEX)]
        
        windows_with_labels__for_feature_set[feature_set]["data"] += [bigdf[index_range[0]:index_range[1]][used_features].to_numpy().flatten() for index_range in windows_ranges]
        windows_with_labels__for_feature_set[feature_set]["labels"] += [1 if bigdf[index_range[0]:index_range[1]][["is_bruxism"]].sum()["is_bruxism"] >= WINDOW_SIZE_INDEX // 2 else 0 for index_range in windows_ranges]
    
    windows_with_labels__for_feature_set[feature_set]["data"] = np.asarray(windows_with_labels__for_feature_set[feature_set]["data"])
    windows_with_labels__for_feature_set[feature_set]["labels"] = np.asarray(windows_with_labels__for_feature_set[feature_set]["labels"])
    # print(f"{feature_set} done")

# %% [markdown]
# # Train time

# %%
# list(windows_with_labels__for_feature_set.keys())[:10]

# %%
# print(windows_with_labels__for_feature_set["ble_gyro"]["data"])

# %%
# with open(f"windows_with_labels__for_feature_set.txt", 'w') as f:
#     print(windows_with_labels__for_feature_set, file=f)

# %%
# windows_with_labels__for_feature_set.keys()

# %%
for k,v in windows_with_labels__for_feature_set.items():
    if len(v["data"]) == 0:
      print(k)
    if len(v["data"]) != len(v["labels"]):
        print(k, len(v["data"]), len(v["labels"]))

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import tree
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

rf_score__by_feature_set = {}
knn_score__by_feature_set = {}
svm_score__by_feature_set = {}
dt_score__by_feature_set = {}
lr_score__by_feature_set = {}

# %%
X_train, X_test, y_train, y_test = train_test_split(windows_with_labels__for_feature_set["bno_quat"]["data"], windows_with_labels__for_feature_set["bno_quat"]["labels"], test_size=0.2)

# model = RandomForestClassifier(n_estimators=10)
model = KNeighborsClassifier(n_neighbors=1)
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.8818747010999521

# %%
for feature_set, data_and_labels in windows_with_labels__for_feature_set.items():
    X_train, X_test, y_train, y_test = train_test_split(data_and_labels["data"], data_and_labels["labels"], test_size=0.2)

    modelRF = RandomForestClassifier(n_estimators=20)
    modelRF.fit(X_train, y_train)
    rf_score__by_feature_set[feature_set] = modelRF.score(X_test, y_test)

rf_score__by_feature_set
# Out:
# {'ble_acc': 0.8455284552845529,
#  'ble_acc,gsr': 0.8402678144428503,
#  'ble_acc,gsr,masseter': 0.8426590148254424,
#  'ble_acc,gsr,masseter,temporalis': 0.8464566929133859,
#  'ble_acc,gsr,temporalis': 0.8519685039370078,
#  'ble_acc,masseter': 0.8565279770444764,
#  'ble_acc,masseter,temporalis': 0.8354330708661417,
#  'ble_acc,temporalis': 0.8354330708661417,
#  'ble_gyro': 0.7307508369201339,
#  'ble_gyro,ble_acc': 0.8455284552845529,
#  'ble_gyro,ble_acc,gsr': 0.8498326159732186,
#  'ble_gyro,ble_acc,gsr,masseter': 0.8637015781922525,
#  'ble_gyro,ble_acc,gsr,masseter,temporalis': 0.8732283464566929,
#  'ble_gyro,ble_acc,gsr,temporalis': 0.8708661417322835,
#  'ble_gyro,ble_acc,masseter': 0.860832137733142,
#  'ble_gyro,ble_acc,masseter,temporalis': 0.8488188976377953,
#  'ble_gyro,ble_acc,temporalis': 0.8496062992125984,
#  'ble_gyro,gsr': 0.803921568627451,
#  'ble_gyro,gsr,masseter': 0.803921568627451,
#  'ble_gyro,gsr,masseter,temporalis': 0.841732283464567,
#  'ble_gyro,gsr,temporalis': 0.8291338582677166,
#  'ble_gyro,masseter': 0.7417503586800573,
#  'ble_gyro,masseter,temporalis': 0.7708661417322835,
#  'ble_gyro,temporalis': 0.7629921259842519,
#  'bno_acc': 0.8436154949784792,
#  'bno_acc,ble_acc': 0.8555714968914395,
#  'bno_acc,ble_acc,gsr': 0.8541367766618843,
#  'bno_acc,ble_acc,gsr,masseter': 0.8493543758967002,
#  'bno_acc,ble_acc,gsr,masseter,temporalis': 0.8763779527559055,
#  'bno_acc,ble_acc,gsr,temporalis': 0.8818897637795275,
#  'bno_acc,ble_acc,masseter': 0.8737446197991392,
#  'bno_acc,ble_acc,masseter,temporalis': 0.8637795275590551,
#  'bno_acc,ble_acc,temporalis': 0.8724409448818897,
#  'bno_acc,ble_gyro': 0.8421807747489239,
#  'bno_acc,ble_gyro,ble_acc': 0.8675274988043998,
#  'bno_acc,ble_gyro,ble_acc,gsr': 0.8727881396461024,
#  'bno_acc,ble_gyro,ble_acc,gsr,masseter': 0.8751793400286944,
#  'bno_acc,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.8929133858267716,
#  'bno_acc,ble_gyro,ble_acc,gsr,temporalis': 0.8889763779527559,
#  'bno_acc,ble_gyro,ble_acc,masseter': 0.8622668579626973,
#  'bno_acc,ble_gyro,ble_acc,masseter,temporalis': 0.9007874015748032,
#  'bno_acc,ble_gyro,ble_acc,temporalis': 0.8850393700787401,
#  'bno_acc,ble_gyro,gsr': 0.8546150167384027,
#  'bno_acc,ble_gyro,gsr,masseter': 0.8766140602582496,
#  'bno_acc,ble_gyro,gsr,masseter,temporalis': 0.8889763779527559,
#  'bno_acc,ble_gyro,gsr,temporalis': 0.8771653543307086,
#  'bno_acc,ble_gyro,masseter': 0.8546150167384027,
#  'bno_acc,ble_gyro,masseter,temporalis': 0.8700787401574803,
#  'bno_acc,ble_gyro,temporalis': 0.8622047244094488,
#  'bno_acc,bno_quat': 0.8857006217120995,
#  'bno_acc,bno_quat,ble_acc': 0.8943089430894309,
#  'bno_acc,bno_quat,ble_acc,gsr': 0.8699186991869918,
#  'bno_acc,bno_quat,ble_acc,gsr,masseter': 0.8766140602582496,
#  'bno_acc,bno_quat,ble_acc,gsr,masseter,temporalis': 0.889763779527559,
#  'bno_acc,bno_quat,ble_acc,gsr,temporalis': 0.9133858267716536,
#  'bno_acc,bno_quat,ble_acc,masseter': 0.874701099952176,
#  'bno_acc,bno_quat,ble_acc,masseter,temporalis': 0.8716535433070867,
#  'bno_acc,bno_quat,ble_acc,temporalis': 0.8960629921259843,
#  'bno_acc,bno_quat,ble_gyro': 0.8900047824007652,
#  'bno_acc,bno_quat,ble_gyro,ble_acc': 0.893352462936394,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,gsr': 0.8861788617886179,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,gsr,masseter': 0.8871353419416547,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.9125984251968504,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,gsr,temporalis': 0.9039370078740158,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,masseter': 0.8900047824007652,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,masseter,temporalis': 0.8952755905511811,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,temporalis': 0.905511811023622,
#  'bno_acc,bno_quat,ble_gyro,gsr': 0.8799617407938786,
#  'bno_acc,bno_quat,ble_gyro,gsr,masseter': 0.8981348637015782,
#  'bno_acc,bno_quat,ble_gyro,gsr,masseter,temporalis': 0.8889763779527559,
#  'bno_acc,bno_quat,ble_gyro,gsr,temporalis': 0.8992125984251969,
#  'bno_acc,bno_quat,ble_gyro,masseter': 0.8866571018651362,
#  'bno_acc,bno_quat,ble_gyro,masseter,temporalis': 0.889763779527559,
#  'bno_acc,bno_quat,ble_gyro,temporalis': 0.8952755905511811,
#  'bno_acc,bno_quat,gsr': 0.8775705404112865,
#  'bno_acc,bno_quat,gsr,masseter': 0.8751793400286944,
#  'bno_acc,bno_quat,gsr,masseter,temporalis': 0.9047244094488189,
#  'bno_acc,bno_quat,gsr,temporalis': 0.8921259842519685,
#  'bno_acc,bno_quat,masseter': 0.8766140602582496,
#  'bno_acc,bno_quat,masseter,temporalis': 0.8984251968503937,
#  'bno_acc,bno_quat,temporalis': 0.8937007874015748,
#  'bno_acc,gsr': 0.8440937350549976,
#  'bno_acc,gsr,masseter': 0.8703969392635102,
#  'bno_acc,gsr,masseter,temporalis': 0.8566929133858268,
#  'bno_acc,gsr,temporalis': 0.8503937007874016,
#  'bno_acc,masseter': 0.8388330942132951,
#  'bno_acc,masseter,temporalis': 0.8464566929133859,
#  'bno_acc,temporalis': 0.84251968503937,
#  'bno_gyro': 0.7407938785270206,
#  'bno_gyro,ble_acc': 0.8531802965088474,
#  'bno_gyro,ble_acc,gsr': 0.8708751793400287,
#  'bno_gyro,ble_acc,gsr,masseter': 0.8622668579626973,
#  'bno_gyro,ble_acc,gsr,masseter,temporalis': 0.8905511811023622,
#  'bno_gyro,ble_acc,gsr,temporalis': 0.8669291338582678,
#  'bno_gyro,ble_acc,masseter': 0.8656145384983261,
#  'bno_gyro,ble_acc,masseter,temporalis': 0.8677165354330708,
#  'bno_gyro,ble_acc,temporalis': 0.852755905511811,
#  'bno_gyro,ble_gyro': 0.7321855571496891,
#  'bno_gyro,ble_gyro,ble_acc': 0.8488761358201817,
#  'bno_gyro,ble_gyro,ble_acc,gsr': 0.8507890961262554,
#  'bno_gyro,ble_gyro,ble_acc,gsr,masseter': 0.8799617407938786,
#  'bno_gyro,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.8929133858267716,
#  'bno_gyro,ble_gyro,ble_acc,gsr,temporalis': 0.8598425196850393,
#  'bno_gyro,ble_gyro,ble_acc,masseter': 0.8675274988043998,
#  'bno_gyro,ble_gyro,ble_acc,masseter,temporalis': 0.8503937007874016,
#  'bno_gyro,ble_gyro,ble_acc,temporalis': 0.8535433070866142,
#  'bno_gyro,ble_gyro,gsr': 0.8101386896221904,
#  'bno_gyro,ble_gyro,gsr,masseter': 0.8058345289335246,
#  'bno_gyro,ble_gyro,gsr,masseter,temporalis': 0.8338582677165355,
#  'bno_gyro,ble_gyro,gsr,temporalis': 0.8307086614173228,
#  'bno_gyro,ble_gyro,masseter': 0.7417503586800573,
#  'bno_gyro,ble_gyro,masseter,temporalis': 0.7503937007874015,
#  'bno_gyro,ble_gyro,temporalis': 0.7417322834645669,
#  'bno_gyro,bno_acc': 0.8498326159732186,
#  'bno_gyro,bno_acc,ble_acc': 0.8861788617886179,
#  'bno_gyro,bno_acc,ble_acc,gsr': 0.882831181252989,
#  'bno_gyro,bno_acc,ble_acc,gsr,masseter': 0.8847441415590627,
#  'bno_gyro,bno_acc,ble_acc,gsr,masseter,temporalis': 0.8740157480314961,
#  'bno_gyro,bno_acc,ble_acc,gsr,temporalis': 0.8913385826771654,
#  'bno_gyro,bno_acc,ble_acc,masseter': 0.8732663797226208,
#  'bno_gyro,bno_acc,ble_acc,masseter,temporalis': 0.8905511811023622,
#  'bno_gyro,bno_acc,ble_acc,temporalis': 0.9047244094488189,
#  'bno_gyro,bno_acc,ble_gyro': 0.8488761358201817,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc': 0.874701099952176,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,gsr': 0.860832137733142,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,gsr,masseter': 0.8876135820181731,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.8889763779527559,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,gsr,temporalis': 0.8905511811023622,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,masseter': 0.8723098995695839,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,masseter,temporalis': 0.8881889763779528,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,temporalis': 0.8818897637795275,
#  'bno_gyro,bno_acc,ble_gyro,gsr': 0.8689622190339551,
#  'bno_gyro,bno_acc,ble_gyro,gsr,masseter': 0.8727881396461024,
#  'bno_gyro,bno_acc,ble_gyro,gsr,masseter,temporalis': 0.889763779527559,
#  'bno_gyro,bno_acc,ble_gyro,gsr,temporalis': 0.8637795275590551,
#  'bno_gyro,bno_acc,ble_gyro,masseter': 0.8560497369679579,
#  'bno_gyro,bno_acc,ble_gyro,masseter,temporalis': 0.8559055118110236,
#  'bno_gyro,bno_acc,ble_gyro,temporalis': 0.8433070866141732,
#  'bno_gyro,bno_acc,bno_quat': 0.9043519846963175,
#  'bno_gyro,bno_acc,bno_quat,ble_acc': 0.8986131037780966,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,gsr': 0.8785270205643233,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,gsr,masseter': 0.8995695839311334,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,gsr,masseter,temporalis': 0.8992125984251969,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,gsr,temporalis': 0.8874015748031496,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,masseter': 0.8900047824007652,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,masseter,temporalis': 0.8937007874015748,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,temporalis': 0.9094488188976378,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro': 0.874701099952176,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc': 0.8895265423242468,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,gsr': 0.8900047824007652,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,gsr,masseter': 0.9000478240076518,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.9007874015748032,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,gsr,temporalis': 0.9023622047244094,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,masseter': 0.9024390243902439,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,masseter,temporalis': 0.905511811023622,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,temporalis': 0.9110236220472441,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,gsr': 0.8962219033955046,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,gsr,masseter': 0.8890483022477284,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,gsr,masseter,temporalis': 0.9,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,gsr,temporalis': 0.9133858267716536,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,masseter': 0.9024390243902439,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,masseter,temporalis': 0.9149606299212598,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,temporalis': 0.8803149606299212,
#  'bno_gyro,bno_acc,bno_quat,gsr': 0.8852223816355811,
#  'bno_gyro,bno_acc,bno_quat,gsr,masseter': 0.8857006217120995,
#  'bno_gyro,bno_acc,bno_quat,gsr,masseter,temporalis': 0.8818897637795275,
#  'bno_gyro,bno_acc,bno_quat,gsr,temporalis': 0.9,
#  'bno_gyro,bno_acc,bno_quat,masseter': 0.8809182209469153,
#  'bno_gyro,bno_acc,bno_quat,masseter,temporalis': 0.9102362204724409,
#  'bno_gyro,bno_acc,bno_quat,temporalis': 0.8944881889763779,
#  'bno_gyro,bno_acc,gsr': 0.8699186991869918,
#  'bno_gyro,bno_acc,gsr,masseter': 0.8718316594930655,
#  'bno_gyro,bno_acc,gsr,masseter,temporalis': 0.8834645669291339,
#  'bno_gyro,bno_acc,gsr,temporalis': 0.8700787401574803,
#  'bno_gyro,bno_acc,masseter': 0.8531802965088474,
#  'bno_gyro,bno_acc,masseter,temporalis': 0.8748031496062992,
#  'bno_gyro,bno_acc,temporalis': 0.8574803149606299,
#  'bno_gyro,bno_quat': 0.8895265423242468,
#  'bno_gyro,bno_quat,ble_acc': 0.8938307030129125,
#  'bno_gyro,bno_quat,ble_acc,gsr': 0.8885700621712099,
#  'bno_gyro,bno_quat,ble_acc,gsr,masseter': 0.9038737446197992,
#  'bno_gyro,bno_quat,ble_acc,gsr,masseter,temporalis': 0.9102362204724409,
#  'bno_gyro,bno_quat,ble_acc,gsr,temporalis': 0.905511811023622,
#  'bno_gyro,bno_quat,ble_acc,masseter': 0.8976566236250598,
#  'bno_gyro,bno_quat,ble_acc,masseter,temporalis': 0.9149606299212598,
#  'bno_gyro,bno_quat,ble_acc,temporalis': 0.9070866141732283,
#  'bno_gyro,bno_quat,ble_gyro': 0.8799617407938786,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc': 0.8890483022477284,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,gsr': 0.890961262553802,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,gsr,masseter': 0.8885700621712099,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.8929133858267716,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,gsr,temporalis': 0.9047244094488189,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,masseter': 0.8890483022477284,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,masseter,temporalis': 0.9,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,temporalis': 0.8944881889763779,
#  'bno_gyro,bno_quat,ble_gyro,gsr': 0.880439980870397,
#  'bno_gyro,bno_quat,ble_gyro,gsr,masseter': 0.882831181252989,
#  'bno_gyro,bno_quat,ble_gyro,gsr,masseter,temporalis': 0.9007874015748032,
#  'bno_gyro,bno_quat,ble_gyro,gsr,temporalis': 0.8937007874015748,
#  'bno_gyro,bno_quat,ble_gyro,masseter': 0.8885700621712099,
#  'bno_gyro,bno_quat,ble_gyro,masseter,temporalis': 0.9125984251968504,
#  'bno_gyro,bno_quat,ble_gyro,temporalis': 0.9031496062992126,
#  'bno_gyro,bno_quat,gsr': 0.896700143472023,
#  'bno_gyro,bno_quat,gsr,masseter': 0.890961262553802,
#  'bno_gyro,bno_quat,gsr,masseter,temporalis': 0.8976377952755905,
#  'bno_gyro,bno_quat,gsr,temporalis': 0.9047244094488189,
#  'bno_gyro,bno_quat,masseter': 0.8938307030129125,
#  'bno_gyro,bno_quat,masseter,temporalis': 0.8960629921259843,
#  'bno_gyro,bno_quat,temporalis': 0.8905511811023622,
#  'bno_gyro,gsr': 0.7690100430416069,
#  'bno_gyro,gsr,masseter': 0.7924438067910091,
#  'bno_gyro,gsr,masseter,temporalis': 0.8141732283464567,
#  'bno_gyro,gsr,temporalis': 0.7874015748031497,
#  'bno_gyro,masseter': 0.7364897178383548,
#  'bno_gyro,masseter,temporalis': 0.7503937007874015,
#  'bno_gyro,temporalis': 0.7094488188976378,
#  'bno_quat': 0.8813964610234337,
#  'bno_quat,ble_acc': 0.8837876614060258,
#  'bno_quat,ble_acc,gsr': 0.8847441415590627,
#  'bno_quat,ble_acc,gsr,masseter': 0.8756575801052128,
#  'bno_quat,ble_acc,gsr,masseter,temporalis': 0.8866141732283465,
#  'bno_quat,ble_acc,gsr,temporalis': 0.8968503937007875,
#  'bno_quat,ble_acc,masseter': 0.8857006217120995,
#  'bno_quat,ble_acc,masseter,temporalis': 0.8795275590551181,
#  'bno_quat,ble_acc,temporalis': 0.8834645669291339,
#  'bno_quat,ble_gyro': 0.8962219033955046,
#  'bno_quat,ble_gyro,ble_acc': 0.890961262553802,
#  'bno_quat,ble_gyro,ble_acc,gsr': 0.8852223816355811,
#  'bno_quat,ble_gyro,ble_acc,gsr,masseter': 0.8962219033955046,
#  'bno_quat,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.8960629921259843,
#  'bno_quat,ble_gyro,ble_acc,gsr,temporalis': 0.9070866141732283,
#  'bno_quat,ble_gyro,ble_acc,masseter': 0.8952654232424677,
#  'bno_quat,ble_gyro,ble_acc,masseter,temporalis': 0.8960629921259843,
#  'bno_quat,ble_gyro,ble_acc,temporalis': 0.9031496062992126,
#  'bno_quat,ble_gyro,gsr': 0.8885700621712099,
#  'bno_quat,ble_gyro,gsr,masseter': 0.8914395026303205,
#  'bno_quat,ble_gyro,gsr,masseter,temporalis': 0.9007874015748032,
#  'bno_quat,ble_gyro,gsr,temporalis': 0.905511811023622,
#  'bno_quat,ble_gyro,masseter': 0.8876135820181731,
#  'bno_quat,ble_gyro,masseter,temporalis': 0.9015748031496063,
#  'bno_quat,ble_gyro,temporalis': 0.9062992125984252,
#  'bno_quat,gsr': 0.8871353419416547,
#  'bno_quat,gsr,masseter': 0.8837876614060258,
#  'bno_quat,gsr,masseter,temporalis': 0.8763779527559055,
#  'bno_quat,gsr,temporalis': 0.8905511811023622,
#  'bno_quat,masseter': 0.8627450980392157,
#  'bno_quat,masseter,temporalis': 0.889763779527559,
#  'bno_quat,temporalis': 0.9039370078740158,
#  'gsr': 0.7149689143950263,
#  'gsr,masseter': 0.779531324725012,
#  'gsr,masseter,temporalis': 0.8,
#  'gsr,temporalis': 0.7803149606299212,
#  'masseter': 0.7197513151602104,
#  'masseter,temporalis': 0.7433070866141732,
#  'temporalis': 0.7259842519685039}

# %%
for feature_set, data_and_labels in windows_with_labels__for_feature_set.items():
    X_train, X_test, y_train, y_test = train_test_split(data_and_labels["data"], data_and_labels["labels"], test_size=0.2)
    modelKNN = KNeighborsClassifier(n_neighbors=5)
    modelKNN.fit(X_train, y_train)
    knn_score__by_feature_set[feature_set] = modelKNN.score(X_test, y_test)

knn_score__by_feature_set
# Out:
# {'ble_acc': 0.820181731229077,
#  'ble_acc,gsr': 0.7350549976087997,
#  'ble_acc,gsr,masseter': 0.6872309899569584,
#  'ble_acc,gsr,masseter,temporalis': 0.6968503937007874,
#  'ble_acc,gsr,temporalis': 0.7023622047244095,
#  'ble_acc,masseter': 0.5671927307508369,
#  'ble_acc,masseter,temporalis': 0.6173228346456693,
#  'ble_acc,temporalis': 0.6204724409448819,
#  'ble_gyro': 0.7302725968436155,
#  'ble_gyro,ble_acc': 0.7293161166905787,
#  'ble_gyro,ble_acc,gsr': 0.7642276422764228,
#  'ble_gyro,ble_acc,gsr,masseter': 0.7092300334768054,
#  'ble_gyro,ble_acc,gsr,masseter,temporalis': 0.7078740157480315,
#  'ble_gyro,ble_acc,gsr,temporalis': 0.7039370078740157,
#  'ble_gyro,ble_acc,masseter': 0.5662362505978001,
#  'ble_gyro,ble_acc,masseter,temporalis': 0.6354330708661418,
#  'ble_gyro,ble_acc,temporalis': 0.6275590551181103,
#  'ble_gyro,gsr': 0.759923481587757,
#  'ble_gyro,gsr,masseter': 0.7154471544715447,
#  'ble_gyro,gsr,masseter,temporalis': 0.6850393700787402,
#  'ble_gyro,gsr,temporalis': 0.7,
#  'ble_gyro,masseter': 0.5872788139646102,
#  'ble_gyro,masseter,temporalis': 0.6527559055118111,
#  'ble_gyro,temporalis': 0.6062992125984252,
#  'bno_acc': 0.8043998087039694,
#  'bno_acc,ble_acc': 0.8177905308464849,
#  'bno_acc,ble_acc,gsr': 0.7685318029650885,
#  'bno_acc,ble_acc,gsr,masseter': 0.7364897178383548,
#  'bno_acc,ble_acc,gsr,masseter,temporalis': 0.7173228346456693,
#  'bno_acc,ble_acc,gsr,temporalis': 0.6763779527559055,
#  'bno_acc,ble_acc,masseter': 0.6131037780966045,
#  'bno_acc,ble_acc,masseter,temporalis': 0.6299212598425197,
#  'bno_acc,ble_acc,temporalis': 0.6173228346456693,
#  'bno_acc,ble_gyro': 0.7685318029650885,
#  'bno_acc,ble_gyro,ble_acc': 0.7651841224294595,
#  'bno_acc,ble_gyro,ble_acc,gsr': 0.7800095648015304,
#  'bno_acc,ble_gyro,ble_acc,gsr,masseter': 0.7259684361549498,
#  'bno_acc,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.6811023622047244,
#  'bno_acc,ble_gyro,ble_acc,gsr,temporalis': 0.684251968503937,
#  'bno_acc,ble_gyro,ble_acc,masseter': 0.6011477761836442,
#  'bno_acc,ble_gyro,ble_acc,masseter,temporalis': 0.647244094488189,
#  'bno_acc,ble_gyro,ble_acc,temporalis': 0.6244094488188976,
#  'bno_acc,ble_gyro,gsr': 0.7833572453371592,
#  'bno_acc,ble_gyro,gsr,masseter': 0.7154471544715447,
#  'bno_acc,ble_gyro,gsr,masseter,temporalis': 0.715748031496063,
#  'bno_acc,ble_gyro,gsr,temporalis': 0.6818897637795276,
#  'bno_acc,ble_gyro,masseter': 0.580105212816834,
#  'bno_acc,ble_gyro,masseter,temporalis': 0.6362204724409449,
#  'bno_acc,ble_gyro,temporalis': 0.6385826771653543,
#  'bno_acc,bno_quat': 0.812051649928264,
#  'bno_acc,bno_quat,ble_acc': 0.8350071736011477,
#  'bno_acc,bno_quat,ble_acc,gsr': 0.759923481587757,
#  'bno_acc,bno_quat,ble_acc,gsr,masseter': 0.7250119560019129,
#  'bno_acc,bno_quat,ble_acc,gsr,masseter,temporalis': 0.6795275590551181,
#  'bno_acc,bno_quat,ble_acc,gsr,temporalis': 0.6937007874015748,
#  'bno_acc,bno_quat,ble_acc,masseter': 0.6260162601626016,
#  'bno_acc,bno_quat,ble_acc,masseter,temporalis': 0.6503937007874016,
#  'bno_acc,bno_quat,ble_acc,temporalis': 0.6433070866141732,
#  'bno_acc,bno_quat,ble_gyro': 0.7780966044954567,
#  'bno_acc,bno_quat,ble_gyro,ble_acc': 0.7690100430416069,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,gsr': 0.7776183644189383,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,gsr,masseter': 0.7187948350071736,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.6968503937007874,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,gsr,temporalis': 0.6881889763779527,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,masseter': 0.5934959349593496,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,masseter,temporalis': 0.6244094488188976,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,temporalis': 0.6433070866141732,
#  'bno_acc,bno_quat,ble_gyro,gsr': 0.7718794835007173,
#  'bno_acc,bno_quat,ble_gyro,gsr,masseter': 0.7340985174557628,
#  'bno_acc,bno_quat,ble_gyro,gsr,masseter,temporalis': 0.7110236220472441,
#  'bno_acc,bno_quat,ble_gyro,gsr,temporalis': 0.684251968503937,
#  'bno_acc,bno_quat,ble_gyro,masseter': 0.5767575322812052,
#  'bno_acc,bno_quat,ble_gyro,masseter,temporalis': 0.6409448818897637,
#  'bno_acc,bno_quat,ble_gyro,temporalis': 0.6267716535433071,
#  'bno_acc,bno_quat,gsr': 0.7670970827355332,
#  'bno_acc,bno_quat,gsr,masseter': 0.7250119560019129,
#  'bno_acc,bno_quat,gsr,masseter,temporalis': 0.7,
#  'bno_acc,bno_quat,gsr,temporalis': 0.6881889763779527,
#  'bno_acc,bno_quat,masseter': 0.6083213773314203,
#  'bno_acc,bno_quat,masseter,temporalis': 0.6409448818897637,
#  'bno_acc,bno_quat,temporalis': 0.6220472440944882,
#  'bno_acc,gsr': 0.7560975609756098,
#  'bno_acc,gsr,masseter': 0.7269249163079866,
#  'bno_acc,gsr,masseter,temporalis': 0.7149606299212599,
#  'bno_acc,gsr,temporalis': 0.6960629921259842,
#  'bno_acc,masseter': 0.6035389765662362,
#  'bno_acc,masseter,temporalis': 0.6220472440944882,
#  'bno_acc,temporalis': 0.6078740157480315,
#  'bno_gyro': 0.7398373983739838,
#  'bno_gyro,ble_acc': 0.8005738880918221,
#  'bno_gyro,ble_acc,gsr': 0.7508369201339072,
#  'bno_gyro,ble_acc,gsr,masseter': 0.7058823529411765,
#  'bno_gyro,ble_acc,gsr,masseter,temporalis': 0.6881889763779527,
#  'bno_gyro,ble_acc,gsr,temporalis': 0.6763779527559055,
#  'bno_gyro,ble_acc,masseter': 0.5906264945002391,
#  'bno_gyro,ble_acc,masseter,temporalis': 0.6078740157480315,
#  'bno_gyro,ble_acc,temporalis': 0.6362204724409449,
#  'bno_gyro,ble_gyro': 0.7245337159253945,
#  'bno_gyro,ble_gyro,ble_acc': 0.7403156384505022,
#  'bno_gyro,ble_gyro,ble_acc,gsr': 0.749402199904352,
#  'bno_gyro,ble_gyro,ble_acc,gsr,masseter': 0.7245337159253945,
#  'bno_gyro,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.6937007874015748,
#  'bno_gyro,ble_gyro,ble_acc,gsr,temporalis': 0.6669291338582677,
#  'bno_gyro,ble_gyro,ble_acc,masseter': 0.583452893352463,
#  'bno_gyro,ble_gyro,ble_acc,masseter,temporalis': 0.6377952755905512,
#  'bno_gyro,ble_gyro,ble_acc,temporalis': 0.6173228346456693,
#  'bno_gyro,ble_gyro,gsr': 0.7508369201339072,
#  'bno_gyro,ble_gyro,gsr,masseter': 0.7197513151602104,
#  'bno_gyro,ble_gyro,gsr,masseter,temporalis': 0.7039370078740157,
#  'bno_gyro,ble_gyro,gsr,temporalis': 0.6874015748031496,
#  'bno_gyro,ble_gyro,masseter': 0.5609756097560976,
#  'bno_gyro,ble_gyro,masseter,temporalis': 0.6385826771653543,
#  'bno_gyro,ble_gyro,temporalis': 0.6456692913385826,
#  'bno_gyro,bno_acc': 0.8077474892395983,
#  'bno_gyro,bno_acc,ble_acc': 0.8168340506934482,
#  'bno_gyro,bno_acc,ble_acc,gsr': 0.7675753228120517,
#  'bno_gyro,bno_acc,ble_acc,gsr,masseter': 0.7058823529411765,
#  'bno_gyro,bno_acc,ble_acc,gsr,masseter,temporalis': 0.6992125984251969,
#  'bno_gyro,bno_acc,ble_acc,gsr,temporalis': 0.6921259842519685,
#  'bno_gyro,bno_acc,ble_acc,masseter': 0.5805834528933524,
#  'bno_gyro,bno_acc,ble_acc,masseter,temporalis': 0.6393700787401575,
#  'bno_gyro,bno_acc,ble_acc,temporalis': 0.6417322834645669,
#  'bno_gyro,bno_acc,ble_gyro': 0.7766618842659014,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc': 0.7776183644189383,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,gsr': 0.7551410808225729,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,gsr,masseter': 0.743663318986131,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.7047244094488189,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,gsr,temporalis': 0.7,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,masseter': 0.583452893352463,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,masseter,temporalis': 0.6433070866141732,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,temporalis': 0.6464566929133858,
#  'bno_gyro,bno_acc,ble_gyro,gsr': 0.7690100430416069,
#  'bno_gyro,bno_acc,ble_gyro,gsr,masseter': 0.7216642754662841,
#  'bno_gyro,bno_acc,ble_gyro,gsr,masseter,temporalis': 0.7062992125984252,
#  'bno_gyro,bno_acc,ble_gyro,gsr,temporalis': 0.6661417322834645,
#  'bno_gyro,bno_acc,ble_gyro,masseter': 0.6035389765662362,
#  'bno_gyro,bno_acc,ble_gyro,masseter,temporalis': 0.6440944881889764,
#  'bno_gyro,bno_acc,ble_gyro,temporalis': 0.6015748031496063,
#  'bno_gyro,bno_acc,bno_quat': 0.8249641319942611,
#  'bno_gyro,bno_acc,bno_quat,ble_acc': 0.830703012912482,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,gsr': 0.7838354854136776,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,gsr,masseter': 0.7211860353897657,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,gsr,masseter,temporalis': 0.705511811023622,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,gsr,temporalis': 0.6850393700787402,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,masseter': 0.6073648971783836,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,masseter,temporalis': 0.6362204724409449,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,temporalis': 0.6181102362204725,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro': 0.776183644189383,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc': 0.7680535628885701,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,gsr': 0.7742706838833094,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,gsr,masseter': 0.7216642754662841,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.7007874015748031,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,gsr,temporalis': 0.6763779527559055,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,masseter': 0.6025824964131994,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,masseter,temporalis': 0.6511811023622047,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,temporalis': 0.6346456692913386,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,gsr': 0.7790530846484935,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,gsr,masseter': 0.7173601147776184,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,gsr,masseter,temporalis': 0.6811023622047244,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,gsr,temporalis': 0.6795275590551181,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,masseter': 0.6064084170253468,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,masseter,temporalis': 0.6338582677165354,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,temporalis': 0.6362204724409449,
#  'bno_gyro,bno_acc,bno_quat,gsr': 0.7608799617407939,
#  'bno_gyro,bno_acc,bno_quat,gsr,masseter': 0.7092300334768054,
#  'bno_gyro,bno_acc,bno_quat,gsr,masseter,temporalis': 0.7039370078740157,
#  'bno_gyro,bno_acc,bno_quat,gsr,temporalis': 0.6952755905511812,
#  'bno_gyro,bno_acc,bno_quat,masseter': 0.6049736967957915,
#  'bno_gyro,bno_acc,bno_quat,masseter,temporalis': 0.6307086614173228,
#  'bno_gyro,bno_acc,bno_quat,temporalis': 0.6259842519685039,
#  'bno_gyro,bno_acc,gsr': 0.7647058823529411,
#  'bno_gyro,bno_acc,gsr,masseter': 0.7039693926351028,
#  'bno_gyro,bno_acc,gsr,masseter,temporalis': 0.7007874015748031,
#  'bno_gyro,bno_acc,gsr,temporalis': 0.6779527559055119,
#  'bno_gyro,bno_acc,masseter': 0.6064084170253468,
#  'bno_gyro,bno_acc,masseter,temporalis': 0.6275590551181103,
#  'bno_gyro,bno_acc,temporalis': 0.6228346456692914,
#  'bno_gyro,bno_quat': 0.820181731229077,
#  'bno_gyro,bno_quat,ble_acc': 0.8268770923003348,
#  'bno_gyro,bno_quat,ble_acc,gsr': 0.7637494021999044,
#  'bno_gyro,bno_quat,ble_acc,gsr,masseter': 0.7393591582974653,
#  'bno_gyro,bno_quat,ble_acc,gsr,masseter,temporalis': 0.7070866141732284,
#  'bno_gyro,bno_quat,ble_acc,gsr,temporalis': 0.6874015748031496,
#  'bno_gyro,bno_quat,ble_acc,masseter': 0.6006695361071258,
#  'bno_gyro,bno_quat,ble_acc,masseter,temporalis': 0.6251968503937008,
#  'bno_gyro,bno_quat,ble_acc,temporalis': 0.6055118110236221,
#  'bno_gyro,bno_quat,ble_gyro': 0.7388809182209469,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc': 0.7369679579148732,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,gsr': 0.7747489239598279,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,gsr,masseter': 0.7326637972262076,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.6968503937007874,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,gsr,temporalis': 0.7039370078740157,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,masseter': 0.5968436154949784,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,masseter,temporalis': 0.6543307086614173,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,temporalis': 0.6251968503937008,
#  'bno_gyro,bno_quat,ble_gyro,gsr': 0.7604017216642754,
#  'bno_gyro,bno_quat,ble_gyro,gsr,masseter': 0.7101865136298422,
#  'bno_gyro,bno_quat,ble_gyro,gsr,masseter,temporalis': 0.705511811023622,
#  'bno_gyro,bno_quat,ble_gyro,gsr,temporalis': 0.6834645669291338,
#  'bno_gyro,bno_quat,ble_gyro,masseter': 0.5810616929698709,
#  'bno_gyro,bno_quat,ble_gyro,masseter,temporalis': 0.6440944881889764,
#  'bno_gyro,bno_quat,ble_gyro,temporalis': 0.6078740157480315,
#  'bno_gyro,bno_quat,gsr': 0.7556193208990913,
#  'bno_gyro,bno_quat,gsr,masseter': 0.729794356767097,
#  'bno_gyro,bno_quat,gsr,masseter,temporalis': 0.6937007874015748,
#  'bno_gyro,bno_quat,gsr,temporalis': 0.6858267716535433,
#  'bno_gyro,bno_quat,masseter': 0.5877570540411287,
#  'bno_gyro,bno_quat,masseter,temporalis': 0.6196850393700788,
#  'bno_gyro,bno_quat,temporalis': 0.6078740157480315,
#  'bno_gyro,gsr': 0.6939263510282162,
#  'bno_gyro,gsr,masseter': 0.7178383548541368,
#  'bno_gyro,gsr,masseter,temporalis': 0.7078740157480315,
#  'bno_gyro,gsr,temporalis': 0.6968503937007874,
#  'bno_gyro,masseter': 0.6011477761836442,
#  'bno_gyro,masseter,temporalis': 0.6503937007874016,
#  'bno_gyro,temporalis': 0.6362204724409449,
#  'bno_quat': 0.8799617407938786,
#  'bno_quat,ble_acc': 0.8876135820181731,
#  'bno_quat,ble_acc,gsr': 0.7661406025824964,
#  'bno_quat,ble_acc,gsr,masseter': 0.7106647537063606,
#  'bno_quat,ble_acc,gsr,masseter,temporalis': 0.7094488188976378,
#  'bno_quat,ble_acc,gsr,temporalis': 0.6850393700787402,
#  'bno_quat,ble_acc,masseter': 0.5738880918220947,
#  'bno_quat,ble_acc,masseter,temporalis': 0.631496062992126,
#  'bno_quat,ble_acc,temporalis': 0.6307086614173228,
#  'bno_quat,ble_gyro': 0.7293161166905787,
#  'bno_quat,ble_gyro,ble_acc': 0.7422285987565758,
#  'bno_quat,ble_gyro,ble_acc,gsr': 0.763271162123386,
#  'bno_quat,ble_gyro,ble_acc,gsr,masseter': 0.7221425155428025,
#  'bno_quat,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.7023622047244095,
#  'bno_quat,ble_gyro,ble_acc,gsr,temporalis': 0.7110236220472441,
#  'bno_quat,ble_gyro,ble_acc,masseter': 0.5796269727403156,
#  'bno_quat,ble_gyro,ble_acc,masseter,temporalis': 0.6047244094488189,
#  'bno_quat,ble_gyro,ble_acc,temporalis': 0.621259842519685,
#  'bno_quat,ble_gyro,gsr': 0.7776183644189383,
#  'bno_quat,ble_gyro,gsr,masseter': 0.7235772357723578,
#  'bno_quat,ble_gyro,gsr,masseter,temporalis': 0.6858267716535433,
#  'bno_quat,ble_gyro,gsr,temporalis': 0.6889763779527559,
#  'bno_quat,ble_gyro,masseter': 0.547584887613582,
#  'bno_quat,ble_gyro,masseter,temporalis': 0.6267716535433071,
#  'bno_quat,ble_gyro,temporalis': 0.6291338582677165,
#  'bno_quat,gsr': 0.7465327594452416,
#  'bno_quat,gsr,masseter': 0.7092300334768054,
#  'bno_quat,gsr,masseter,temporalis': 0.7220472440944882,
#  'bno_quat,gsr,temporalis': 0.7070866141732284,
#  'bno_quat,masseter': 0.5992348158775705,
#  'bno_quat,masseter,temporalis': 0.6401574803149607,
#  'bno_quat,temporalis': 0.6204724409448819,
#  'gsr': 0.697274031563845,
#  'gsr,masseter': 0.7226207556193209,
#  'gsr,masseter,temporalis': 0.6858267716535433,
#  'gsr,temporalis': 0.7015748031496063,
#  'masseter': 0.583452893352463,
#  'masseter,temporalis': 0.631496062992126,
#  'temporalis': 0.6204724409448819}

# %%
for feature_set, data_and_labels in windows_with_labels__for_feature_set.items():
    X_train, X_test, y_train, y_test = train_test_split(data_and_labels["data"], data_and_labels["labels"], test_size=0.2)
    modelSVM = SVC()
    modelSVM.fit(X_train, y_train)
    svm_score__by_feature_set[feature_set] = modelSVM.score(X_test, y_test)

svm_score__by_feature_set
# Out:
# {'ble_acc': 0.7144906743185079,
#  'ble_acc,gsr': 0.697274031563845,
#  'ble_acc,gsr,masseter': 0.7058823529411765,
#  'ble_acc,gsr,masseter,temporalis': 0.6874015748031496,
#  'ble_acc,gsr,temporalis': 0.6834645669291338,
#  'ble_acc,masseter': 0.6905786704925873,
#  'ble_acc,masseter,temporalis': 0.6700787401574804,
#  'ble_acc,temporalis': 0.7007874015748031,
#  'ble_gyro': 0.7403156384505022,
#  'ble_gyro,ble_acc': 0.7541846006695361,
#  'ble_gyro,ble_acc,gsr': 0.6924916307986609,
#  'ble_gyro,ble_acc,gsr,masseter': 0.7010999521759923,
#  'ble_gyro,ble_acc,gsr,masseter,temporalis': 0.6771653543307087,
#  'ble_gyro,ble_acc,gsr,temporalis': 0.6874015748031496,
#  'ble_gyro,ble_acc,masseter': 0.7140124342419895,
#  'ble_gyro,ble_acc,masseter,temporalis': 0.6992125984251969,
#  'ble_gyro,ble_acc,temporalis': 0.662992125984252,
#  'ble_gyro,gsr': 0.6948828311812529,
#  'ble_gyro,gsr,masseter': 0.7087517934002869,
#  'ble_gyro,gsr,masseter,temporalis': 0.6929133858267716,
#  'ble_gyro,gsr,temporalis': 0.6960629921259842,
#  'ble_gyro,masseter': 0.7044476327116213,
#  'ble_gyro,masseter,temporalis': 0.6929133858267716,
#  'ble_gyro,temporalis': 0.6913385826771653,
#  'bno_acc': 0.7317073170731707,
#  'bno_acc,ble_acc': 0.7077953132472501,
#  'bno_acc,ble_acc,gsr': 0.7106647537063606,
#  'bno_acc,ble_acc,gsr,masseter': 0.6963175514108082,
#  'bno_acc,ble_acc,gsr,masseter,temporalis': 0.6889763779527559,
#  'bno_acc,ble_acc,gsr,temporalis': 0.6992125984251969,
#  'bno_acc,ble_acc,masseter': 0.7101865136298422,
#  'bno_acc,ble_acc,masseter,temporalis': 0.6598425196850394,
#  'bno_acc,ble_acc,temporalis': 0.7031496062992126,
#  'bno_acc,ble_gyro': 0.7350549976087997,
#  'bno_acc,ble_gyro,ble_acc': 0.7570540411286466,
#  'bno_acc,ble_gyro,ble_acc,gsr': 0.6886657101865137,
#  'bno_acc,ble_gyro,ble_acc,gsr,masseter': 0.6795791487326638,
#  'bno_acc,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.6818897637795276,
#  'bno_acc,ble_gyro,ble_acc,gsr,temporalis': 0.7078740157480315,
#  'bno_acc,ble_gyro,ble_acc,masseter': 0.7092300334768054,
#  'bno_acc,ble_gyro,ble_acc,masseter,temporalis': 0.6669291338582677,
#  'bno_acc,ble_gyro,ble_acc,temporalis': 0.6661417322834645,
#  'bno_acc,ble_gyro,gsr': 0.7101865136298422,
#  'bno_acc,ble_gyro,gsr,masseter': 0.6910569105691057,
#  'bno_acc,ble_gyro,gsr,masseter,temporalis': 0.7062992125984252,
#  'bno_acc,ble_gyro,gsr,temporalis': 0.6669291338582677,
#  'bno_acc,ble_gyro,masseter': 0.6991869918699187,
#  'bno_acc,ble_gyro,masseter,temporalis': 0.6850393700787402,
#  'bno_acc,ble_gyro,temporalis': 0.6850393700787402,
#  'bno_acc,bno_quat': 0.7254901960784313,
#  'bno_acc,bno_quat,ble_acc': 0.7216642754662841,
#  'bno_acc,bno_quat,ble_acc,gsr': 0.6915351506456241,
#  'bno_acc,bno_quat,ble_acc,gsr,masseter': 0.7077953132472501,
#  'bno_acc,bno_quat,ble_acc,gsr,masseter,temporalis': 0.6866141732283465,
#  'bno_acc,bno_quat,ble_acc,gsr,temporalis': 0.6803149606299213,
#  'bno_acc,bno_quat,ble_acc,masseter': 0.6915351506456241,
#  'bno_acc,bno_quat,ble_acc,masseter,temporalis': 0.7015748031496063,
#  'bno_acc,bno_quat,ble_acc,temporalis': 0.6889763779527559,
#  'bno_acc,bno_quat,ble_gyro': 0.743663318986131,
#  'bno_acc,bno_quat,ble_gyro,ble_acc': 0.7264466762314682,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,gsr': 0.6987087517934003,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,gsr,masseter': 0.7082735533237685,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.6763779527559055,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,gsr,temporalis': 0.6992125984251969,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,masseter': 0.6905786704925873,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,masseter,temporalis': 0.6874015748031496,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,temporalis': 0.6897637795275591,
#  'bno_acc,bno_quat,ble_gyro,gsr': 0.6996652319464371,
#  'bno_acc,bno_quat,ble_gyro,gsr,masseter': 0.68675274988044,
#  'bno_acc,bno_quat,ble_gyro,gsr,masseter,temporalis': 0.6763779527559055,
#  'bno_acc,bno_quat,ble_gyro,gsr,temporalis': 0.7023622047244095,
#  'bno_acc,bno_quat,ble_gyro,masseter': 0.6958393113342898,
#  'bno_acc,bno_quat,ble_gyro,masseter,temporalis': 0.6937007874015748,
#  'bno_acc,bno_quat,ble_gyro,temporalis': 0.6795275590551181,
#  'bno_acc,bno_quat,gsr': 0.7049258727881397,
#  'bno_acc,bno_quat,gsr,masseter': 0.6977522716403635,
#  'bno_acc,bno_quat,gsr,masseter,temporalis': 0.6992125984251969,
#  'bno_acc,bno_quat,gsr,temporalis': 0.6787401574803149,
#  'bno_acc,bno_quat,masseter': 0.6896221903395504,
#  'bno_acc,bno_quat,masseter,temporalis': 0.6937007874015748,
#  'bno_acc,bno_quat,temporalis': 0.6881889763779527,
#  'bno_acc,gsr': 0.7020564323290291,
#  'bno_acc,gsr,masseter': 0.7006217120994739,
#  'bno_acc,gsr,masseter,temporalis': 0.6976377952755906,
#  'bno_acc,gsr,temporalis': 0.6598425196850394,
#  'bno_acc,masseter': 0.6953610712577714,
#  'bno_acc,masseter,temporalis': 0.6889763779527559,
#  'bno_acc,temporalis': 0.6858267716535433,
#  'bno_gyro': 0.7450980392156863,
#  'bno_gyro,ble_acc': 0.7202295552367288,
#  'bno_gyro,ble_acc,gsr': 0.6872309899569584,
#  'bno_gyro,ble_acc,gsr,masseter': 0.6896221903395504,
#  'bno_gyro,ble_acc,gsr,masseter,temporalis': 0.6858267716535433,
#  'bno_gyro,ble_acc,gsr,temporalis': 0.7015748031496063,
#  'bno_gyro,ble_acc,masseter': 0.6939263510282162,
#  'bno_gyro,ble_acc,masseter,temporalis': 0.6677165354330709,
#  'bno_gyro,ble_acc,temporalis': 0.6889763779527559,
#  'bno_gyro,ble_gyro': 0.7216642754662841,
#  'bno_gyro,ble_gyro,ble_acc': 0.7312290769966523,
#  'bno_gyro,ble_gyro,ble_acc,gsr': 0.6948828311812529,
#  'bno_gyro,ble_gyro,ble_acc,gsr,masseter': 0.7092300334768054,
#  'bno_gyro,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.6913385826771653,
#  'bno_gyro,ble_gyro,ble_acc,gsr,temporalis': 0.6818897637795276,
#  'bno_gyro,ble_gyro,ble_acc,masseter': 0.6991869918699187,
#  'bno_gyro,ble_gyro,ble_acc,masseter,temporalis': 0.6874015748031496,
#  'bno_gyro,ble_gyro,ble_acc,temporalis': 0.7031496062992126,
#  'bno_gyro,ble_gyro,gsr': 0.7073170731707317,
#  'bno_gyro,ble_gyro,gsr,masseter': 0.6872309899569584,
#  'bno_gyro,ble_gyro,gsr,masseter,temporalis': 0.6960629921259842,
#  'bno_gyro,ble_gyro,gsr,temporalis': 0.6960629921259842,
#  'bno_gyro,ble_gyro,masseter': 0.6910569105691057,
#  'bno_gyro,ble_gyro,masseter,temporalis': 0.6834645669291338,
#  'bno_gyro,ble_gyro,temporalis': 0.6858267716535433,
#  'bno_gyro,bno_acc': 0.7187948350071736,
#  'bno_gyro,bno_acc,ble_acc': 0.733142037302726,
#  'bno_gyro,bno_acc,ble_acc,gsr': 0.7001434720229556,
#  'bno_gyro,bno_acc,ble_acc,gsr,masseter': 0.6996652319464371,
#  'bno_gyro,bno_acc,ble_acc,gsr,masseter,temporalis': 0.6881889763779527,
#  'bno_gyro,bno_acc,ble_acc,gsr,temporalis': 0.6858267716535433,
#  'bno_gyro,bno_acc,ble_acc,masseter': 0.6910569105691057,
#  'bno_gyro,bno_acc,ble_acc,masseter,temporalis': 0.6716535433070866,
#  'bno_gyro,bno_acc,ble_acc,temporalis': 0.6952755905511812,
#  'bno_gyro,bno_acc,ble_gyro': 0.7455762792922047,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc': 0.7446197991391679,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,gsr': 0.7077953132472501,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,gsr,masseter': 0.68675274988044,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.6811023622047244,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,gsr,temporalis': 0.6590551181102362,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,masseter': 0.7164036346245816,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,masseter,temporalis': 0.6866141732283465,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,temporalis': 0.6905511811023622,
#  'bno_gyro,bno_acc,ble_gyro,gsr': 0.7034911525585844,
#  'bno_gyro,bno_acc,ble_gyro,gsr,masseter': 0.7025346724055476,
#  'bno_gyro,bno_acc,ble_gyro,gsr,masseter,temporalis': 0.705511811023622,
#  'bno_gyro,bno_acc,ble_gyro,gsr,temporalis': 0.694488188976378,
#  'bno_gyro,bno_acc,ble_gyro,masseter': 0.7068388330942132,
#  'bno_gyro,bno_acc,ble_gyro,masseter,temporalis': 0.715748031496063,
#  'bno_gyro,bno_acc,ble_gyro,temporalis': 0.6700787401574804,
#  'bno_gyro,bno_acc,bno_quat': 0.7269249163079866,
#  'bno_gyro,bno_acc,bno_quat,ble_acc': 0.7140124342419895,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,gsr': 0.7125777140124342,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,gsr,masseter': 0.7125777140124342,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,gsr,masseter,temporalis': 0.6779527559055119,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,gsr,temporalis': 0.6984251968503937,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,masseter': 0.6877092300334768,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,masseter,temporalis': 0.7118110236220473,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,temporalis': 0.6881889763779527,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro': 0.7446197991391679,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc': 0.7551410808225729,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,gsr': 0.6987087517934003,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,gsr,masseter': 0.6924916307986609,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.6700787401574804,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,gsr,temporalis': 0.7047244094488189,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,masseter': 0.6886657101865137,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,masseter,temporalis': 0.6937007874015748,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,temporalis': 0.6740157480314961,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,gsr': 0.7063605930176949,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,gsr,masseter': 0.6915351506456241,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,gsr,masseter,temporalis': 0.7110236220472441,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,gsr,temporalis': 0.6913385826771653,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,masseter': 0.7020564323290291,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,masseter,temporalis': 0.6905511811023622,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,temporalis': 0.6952755905511812,
#  'bno_gyro,bno_acc,bno_quat,gsr': 0.6910569105691057,
#  'bno_gyro,bno_acc,bno_quat,gsr,masseter': 0.7092300334768054,
#  'bno_gyro,bno_acc,bno_quat,gsr,masseter,temporalis': 0.6984251968503937,
#  'bno_gyro,bno_acc,bno_quat,gsr,temporalis': 0.6748031496062992,
#  'bno_gyro,bno_acc,bno_quat,masseter': 0.6987087517934003,
#  'bno_gyro,bno_acc,bno_quat,masseter,temporalis': 0.6716535433070866,
#  'bno_gyro,bno_acc,bno_quat,temporalis': 0.6787401574803149,
#  'bno_gyro,bno_acc,gsr': 0.713534194165471,
#  'bno_gyro,bno_acc,gsr,masseter': 0.7025346724055476,
#  'bno_gyro,bno_acc,gsr,masseter,temporalis': 0.6976377952755906,
#  'bno_gyro,bno_acc,gsr,temporalis': 0.6968503937007874,
#  'bno_gyro,bno_acc,masseter': 0.6819703491152559,
#  'bno_gyro,bno_acc,masseter,temporalis': 0.6968503937007874,
#  'bno_gyro,bno_acc,temporalis': 0.6637795275590551,
#  'bno_gyro,bno_quat': 0.7317073170731707,
#  'bno_gyro,bno_quat,ble_acc': 0.7278813964610235,
#  'bno_gyro,bno_quat,ble_acc,gsr': 0.7044476327116213,
#  'bno_gyro,bno_quat,ble_acc,gsr,masseter': 0.7001434720229556,
#  'bno_gyro,bno_quat,ble_acc,gsr,masseter,temporalis': 0.6937007874015748,
#  'bno_gyro,bno_quat,ble_acc,gsr,temporalis': 0.6937007874015748,
#  'bno_gyro,bno_quat,ble_acc,masseter': 0.7034911525585844,
#  'bno_gyro,bno_quat,ble_acc,masseter,temporalis': 0.6913385826771653,
#  'bno_gyro,bno_quat,ble_acc,temporalis': 0.6874015748031496,
#  'bno_gyro,bno_quat,ble_gyro': 0.7556193208990913,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc': 0.7584887613582019,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,gsr': 0.6987087517934003,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,gsr,masseter': 0.7068388330942132,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.6874015748031496,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,gsr,temporalis': 0.6622047244094488,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,masseter': 0.6824485891917743,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,masseter,temporalis': 0.6811023622047244,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,temporalis': 0.6913385826771653,
#  'bno_gyro,bno_quat,ble_gyro,gsr': 0.6939263510282162,
#  'bno_gyro,bno_quat,ble_gyro,gsr,masseter': 0.689143950263032,
#  'bno_gyro,bno_quat,ble_gyro,gsr,masseter,temporalis': 0.7031496062992126,
#  'bno_gyro,bno_quat,ble_gyro,gsr,temporalis': 0.7031496062992126,
#  'bno_gyro,bno_quat,ble_gyro,masseter': 0.6991869918699187,
#  'bno_gyro,bno_quat,ble_gyro,masseter,temporalis': 0.6881889763779527,
#  'bno_gyro,bno_quat,ble_gyro,temporalis': 0.6779527559055119,
#  'bno_gyro,bno_quat,gsr': 0.6991869918699187,
#  'bno_gyro,bno_quat,gsr,masseter': 0.7001434720229556,
#  'bno_gyro,bno_quat,gsr,masseter,temporalis': 0.6858267716535433,
#  'bno_gyro,bno_quat,gsr,temporalis': 0.6874015748031496,
#  'bno_gyro,bno_quat,masseter': 0.7010999521759923,
#  'bno_gyro,bno_quat,masseter,temporalis': 0.6929133858267716,
#  'bno_gyro,bno_quat,temporalis': 0.6850393700787402,
#  'bno_gyro,gsr': 0.6934481109516978,
#  'bno_gyro,gsr,masseter': 0.6991869918699187,
#  'bno_gyro,gsr,masseter,temporalis': 0.7,
#  'bno_gyro,gsr,temporalis': 0.6976377952755906,
#  'bno_gyro,masseter': 0.6877092300334768,
#  'bno_gyro,masseter,temporalis': 0.6826771653543308,
#  'bno_gyro,temporalis': 0.6748031496062992,
#  'bno_quat': 0.7245337159253945,
#  'bno_quat,ble_acc': 0.7479674796747967,
#  'bno_quat,ble_acc,gsr': 0.6939263510282162,
#  'bno_quat,ble_acc,gsr,masseter': 0.6910569105691057,
#  'bno_quat,ble_acc,gsr,masseter,temporalis': 0.6992125984251969,
#  'bno_quat,ble_acc,gsr,temporalis': 0.6811023622047244,
#  'bno_quat,ble_acc,masseter': 0.6977522716403635,
#  'bno_quat,ble_acc,masseter,temporalis': 0.6905511811023622,
#  'bno_quat,ble_acc,temporalis': 0.6818897637795276,
#  'bno_quat,ble_gyro': 0.7235772357723578,
#  'bno_quat,ble_gyro,ble_acc': 0.7474892395982783,
#  'bno_quat,ble_gyro,ble_acc,gsr': 0.6924916307986609,
#  'bno_quat,ble_gyro,ble_acc,gsr,masseter': 0.6944045911047346,
#  'bno_quat,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.7110236220472441,
#  'bno_quat,ble_gyro,ble_acc,gsr,temporalis': 0.6779527559055119,
#  'bno_quat,ble_gyro,ble_acc,masseter': 0.7092300334768054,
#  'bno_quat,ble_gyro,ble_acc,masseter,temporalis': 0.6803149606299213,
#  'bno_quat,ble_gyro,ble_acc,temporalis': 0.6818897637795276,
#  'bno_quat,ble_gyro,gsr': 0.6996652319464371,
#  'bno_quat,ble_gyro,gsr,masseter': 0.6958393113342898,
#  'bno_quat,ble_gyro,gsr,masseter,temporalis': 0.6732283464566929,
#  'bno_quat,ble_gyro,gsr,temporalis': 0.6811023622047244,
#  'bno_quat,ble_gyro,masseter': 0.6967957914873266,
#  'bno_quat,ble_gyro,masseter,temporalis': 0.6929133858267716,
#  'bno_quat,ble_gyro,temporalis': 0.6905511811023622,
#  'bno_quat,gsr': 0.6944045911047346,
#  'bno_quat,gsr,masseter': 0.7164036346245816,
#  'bno_quat,gsr,masseter,temporalis': 0.6874015748031496,
#  'bno_quat,gsr,temporalis': 0.6960629921259842,
#  'bno_quat,masseter': 0.7025346724055476,
#  'bno_quat,masseter,temporalis': 0.6763779527559055,
#  'bno_quat,temporalis': 0.6881889763779527,
#  'gsr': 0.719273075083692,
#  'gsr,masseter': 0.697274031563845,
#  'gsr,masseter,temporalis': 0.7173228346456693,
#  'gsr,temporalis': 0.7228346456692913,
#  'masseter': 0.6829268292682927,
#  'masseter,temporalis': 0.6850393700787402,
#  'temporalis': 0.6692913385826772}

# %%
for feature_set, data_and_labels in windows_with_labels__for_feature_set.items():
    X_train, X_test, y_train, y_test = train_test_split(data_and_labels["data"], data_and_labels["labels"], test_size=0.2)
    modelDT = tree.DecisionTreeClassifier()
    modelDT.fit(X_train, y_train)
    dt_score__by_feature_set[feature_set] = modelDT.score(X_test, y_test)

dt_score__by_feature_set
# Out:
# {'ble_acc': 0.7847919655667145,
#  'ble_acc,gsr': 0.7881396461023433,
#  'ble_acc,gsr,masseter': 0.8053562888570062,
#  'ble_acc,gsr,masseter,temporalis': 0.8244094488188977,
#  'ble_acc,gsr,temporalis': 0.8007874015748031,
#  'ble_acc,masseter': 0.7824007651841224,
#  'ble_acc,masseter,temporalis': 0.7850393700787401,
#  'ble_acc,temporalis': 0.7637795275590551,
#  'ble_gyro': 0.6465805834528934,
#  'ble_gyro,ble_acc': 0.7728359636537542,
#  'ble_gyro,ble_acc,gsr': 0.795791487326638,
#  'ble_gyro,ble_acc,gsr,masseter': 0.7948350071736011,
#  'ble_gyro,ble_acc,gsr,masseter,temporalis': 0.8377952755905512,
#  'ble_gyro,ble_acc,gsr,temporalis': 0.8031496062992126,
#  'ble_gyro,ble_acc,masseter': 0.8015303682448589,
#  'ble_gyro,ble_acc,masseter,temporalis': 0.7881889763779527,
#  'ble_gyro,ble_acc,temporalis': 0.7960629921259843,
#  'ble_gyro,gsr': 0.719273075083692,
#  'ble_gyro,gsr,masseter': 0.7398373983739838,
#  'ble_gyro,gsr,masseter,temporalis': 0.7543307086614173,
#  'ble_gyro,gsr,temporalis': 0.7464566929133858,
#  'ble_gyro,masseter': 0.6518412242945959,
#  'ble_gyro,masseter,temporalis': 0.6716535433070866,
#  'ble_gyro,temporalis': 0.6425196850393701,
#  'bno_acc': 0.7886178861788617,
#  'bno_acc,ble_acc': 0.795791487326638,
#  'bno_acc,ble_acc,gsr': 0.7981826877092301,
#  'bno_acc,ble_acc,gsr,masseter': 0.809660449545672,
#  'bno_acc,ble_acc,gsr,masseter,temporalis': 0.8165354330708662,
#  'bno_acc,ble_acc,gsr,temporalis': 0.8228346456692913,
#  'bno_acc,ble_acc,masseter': 0.8015303682448589,
#  'bno_acc,ble_acc,masseter,temporalis': 0.8007874015748031,
#  'bno_acc,ble_acc,temporalis': 0.8149606299212598,
#  'bno_acc,ble_gyro': 0.7580105212816834,
#  'bno_acc,ble_gyro,ble_acc': 0.7977044476327116,
#  'bno_acc,ble_gyro,ble_acc,gsr': 0.8005738880918221,
#  'bno_acc,ble_gyro,ble_acc,gsr,masseter': 0.809660449545672,
#  'bno_acc,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.8543307086614174,
#  'bno_acc,ble_gyro,ble_acc,gsr,temporalis': 0.8031496062992126,
#  'bno_acc,ble_gyro,ble_acc,masseter': 0.8000956480153036,
#  'bno_acc,ble_gyro,ble_acc,masseter,temporalis': 0.8173228346456692,
#  'bno_acc,ble_gyro,ble_acc,temporalis': 0.8188976377952756,
#  'bno_acc,ble_gyro,gsr': 0.790052606408417,
#  'bno_acc,ble_gyro,gsr,masseter': 0.7938785270205643,
#  'bno_acc,ble_gyro,gsr,masseter,temporalis': 0.8165354330708662,
#  'bno_acc,ble_gyro,gsr,temporalis': 0.8181102362204724,
#  'bno_acc,ble_gyro,masseter': 0.776183644189383,
#  'bno_acc,ble_gyro,masseter,temporalis': 0.7858267716535433,
#  'bno_acc,ble_gyro,temporalis': 0.7614173228346457,
#  'bno_acc,bno_quat': 0.8230511716881874,
#  'bno_acc,bno_quat,ble_acc': 0.8263988522238164,
#  'bno_acc,bno_quat,ble_acc,gsr': 0.839789574366332,
#  'bno_acc,bno_quat,ble_acc,gsr,masseter': 0.8273553323768532,
#  'bno_acc,bno_quat,ble_acc,gsr,masseter,temporalis': 0.8338582677165355,
#  'bno_acc,bno_quat,ble_acc,gsr,temporalis': 0.8362204724409449,
#  'bno_acc,bno_quat,ble_acc,masseter': 0.8283118125298901,
#  'bno_acc,bno_quat,ble_acc,masseter,temporalis': 0.8393700787401575,
#  'bno_acc,bno_quat,ble_acc,temporalis': 0.8291338582677166,
#  'bno_acc,bno_quat,ble_gyro': 0.8153993304638929,
#  'bno_acc,bno_quat,ble_gyro,ble_acc': 0.8230511716881874,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,gsr': 0.830703012912482,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,gsr,masseter': 0.8244858919177427,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.8645669291338582,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,gsr,temporalis': 0.8456692913385827,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,masseter': 0.8330942132950742,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,masseter,temporalis': 0.8551181102362204,
#  'bno_acc,bno_quat,ble_gyro,ble_acc,temporalis': 0.8377952755905512,
#  'bno_acc,bno_quat,ble_gyro,gsr': 0.8067910090865614,
#  'bno_acc,bno_quat,ble_gyro,gsr,masseter': 0.8182687709230033,
#  'bno_acc,bno_quat,ble_gyro,gsr,masseter,temporalis': 0.8535433070866142,
#  'bno_acc,bno_quat,ble_gyro,gsr,temporalis': 0.841732283464567,
#  'bno_acc,bno_quat,ble_gyro,masseter': 0.8139646102343376,
#  'bno_acc,bno_quat,ble_gyro,masseter,temporalis': 0.8496062992125984,
#  'bno_acc,bno_quat,ble_gyro,temporalis': 0.8551181102362204,
#  'bno_acc,bno_quat,gsr': 0.8153993304638929,
#  'bno_acc,bno_quat,gsr,masseter': 0.8173122907699665,
#  'bno_acc,bno_quat,gsr,masseter,temporalis': 0.8433070866141732,
#  'bno_acc,bno_quat,gsr,temporalis': 0.841732283464567,
#  'bno_acc,bno_quat,masseter': 0.8110951697752271,
#  'bno_acc,bno_quat,masseter,temporalis': 0.8519685039370078,
#  'bno_acc,bno_quat,temporalis': 0.8228346456692913,
#  'bno_acc,gsr': 0.7919655667144907,
#  'bno_acc,gsr,masseter': 0.8000956480153036,
#  'bno_acc,gsr,masseter,temporalis': 0.8094488188976378,
#  'bno_acc,gsr,temporalis': 0.8086614173228347,
#  'bno_acc,masseter': 0.7627929220468675,
#  'bno_acc,masseter,temporalis': 0.7866141732283465,
#  'bno_acc,temporalis': 0.7763779527559055,
#  'bno_gyro': 0.6288857006217121,
#  'bno_gyro,ble_acc': 0.7852702056432329,
#  'bno_gyro,ble_acc,gsr': 0.8163558106169297,
#  'bno_gyro,ble_acc,gsr,masseter': 0.7953132472501195,
#  'bno_gyro,ble_acc,gsr,masseter,temporalis': 0.8299212598425196,
#  'bno_gyro,ble_acc,gsr,temporalis': 0.8141732283464567,
#  'bno_gyro,ble_acc,masseter': 0.779531324725012,
#  'bno_gyro,ble_acc,masseter,temporalis': 0.8,
#  'bno_gyro,ble_acc,temporalis': 0.7881889763779527,
#  'bno_gyro,ble_gyro': 0.6284074605451937,
#  'bno_gyro,ble_gyro,ble_acc': 0.7824007651841224,
#  'bno_gyro,ble_gyro,ble_acc,gsr': 0.8024868483978957,
#  'bno_gyro,ble_gyro,ble_acc,gsr,masseter': 0.8220946915351507,
#  'bno_gyro,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.8259842519685039,
#  'bno_gyro,ble_gyro,ble_acc,gsr,temporalis': 0.8228346456692913,
#  'bno_gyro,ble_gyro,ble_acc,masseter': 0.7766618842659014,
#  'bno_gyro,ble_gyro,ble_acc,masseter,temporalis': 0.7960629921259843,
#  'bno_gyro,ble_gyro,ble_acc,temporalis': 0.805511811023622,
#  'bno_gyro,ble_gyro,gsr': 0.7130559540889526,
#  'bno_gyro,ble_gyro,gsr,masseter': 0.7278813964610235,
#  'bno_gyro,ble_gyro,gsr,masseter,temporalis': 0.7661417322834646,
#  'bno_gyro,ble_gyro,gsr,temporalis': 0.7393700787401575,
#  'bno_gyro,ble_gyro,masseter': 0.662362505978001,
#  'bno_gyro,ble_gyro,masseter,temporalis': 0.6818897637795276,
#  'bno_gyro,ble_gyro,temporalis': 0.658267716535433,
#  'bno_gyro,bno_acc': 0.7809660449545672,
#  'bno_gyro,bno_acc,ble_acc': 0.8125298900047824,
#  'bno_gyro,bno_acc,ble_acc,gsr': 0.8106169296987088,
#  'bno_gyro,bno_acc,ble_acc,gsr,masseter': 0.8240076518412243,
#  'bno_gyro,bno_acc,ble_acc,gsr,masseter,temporalis': 0.8165354330708662,
#  'bno_gyro,bno_acc,ble_acc,gsr,temporalis': 0.8244094488188977,
#  'bno_gyro,bno_acc,ble_acc,masseter': 0.8187470109995217,
#  'bno_gyro,bno_acc,ble_acc,masseter,temporalis': 0.8062992125984252,
#  'bno_gyro,bno_acc,ble_acc,temporalis': 0.8362204724409449,
#  'bno_gyro,bno_acc,ble_gyro': 0.7541846006695361,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc': 0.7986609277857485,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,gsr': 0.795791487326638,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,gsr,masseter': 0.8115734098517455,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.8220472440944881,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,gsr,temporalis': 0.8259842519685039,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,masseter': 0.7991391678622669,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,masseter,temporalis': 0.8330708661417323,
#  'bno_gyro,bno_acc,ble_gyro,ble_acc,temporalis': 0.8220472440944881,
#  'bno_gyro,bno_acc,ble_gyro,gsr': 0.7890961262553802,
#  'bno_gyro,bno_acc,ble_gyro,gsr,masseter': 0.8125298900047824,
#  'bno_gyro,bno_acc,ble_gyro,gsr,masseter,temporalis': 0.805511811023622,
#  'bno_gyro,bno_acc,ble_gyro,gsr,temporalis': 0.8,
#  'bno_gyro,bno_acc,ble_gyro,masseter': 0.779531324725012,
#  'bno_gyro,bno_acc,ble_gyro,masseter,temporalis': 0.7811023622047244,
#  'bno_gyro,bno_acc,ble_gyro,temporalis': 0.75748031496063,
#  'bno_gyro,bno_acc,bno_quat': 0.8125298900047824,
#  'bno_gyro,bno_acc,bno_quat,ble_acc': 0.8292682926829268,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,gsr': 0.8144428503108561,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,gsr,masseter': 0.820181731229077,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,gsr,masseter,temporalis': 0.8464566929133859,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,gsr,temporalis': 0.8440944881889764,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,masseter': 0.8278335724533716,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,masseter,temporalis': 0.8409448818897638,
#  'bno_gyro,bno_acc,bno_quat,ble_acc,temporalis': 0.8330708661417323,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro': 0.8034433285509326,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc': 0.8369201339072214,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,gsr': 0.8091822094691535,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,gsr,masseter': 0.8125298900047824,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.8519685039370078,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,gsr,temporalis': 0.8480314960629921,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,masseter': 0.8263988522238164,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,masseter,temporalis': 0.8283464566929134,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,ble_acc,temporalis': 0.84251968503937,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,gsr': 0.8187470109995217,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,gsr,masseter': 0.8091822094691535,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,gsr,masseter,temporalis': 0.8133858267716535,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,gsr,temporalis': 0.8322834645669291,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,masseter': 0.830703012912482,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,masseter,temporalis': 0.8480314960629921,
#  'bno_gyro,bno_acc,bno_quat,ble_gyro,temporalis': 0.8338582677165355,
#  'bno_gyro,bno_acc,bno_quat,gsr': 0.7938785270205643,
#  'bno_gyro,bno_acc,bno_quat,gsr,masseter': 0.8134863701578192,
#  'bno_gyro,bno_acc,bno_quat,gsr,masseter,temporalis': 0.8511811023622047,
#  'bno_gyro,bno_acc,bno_quat,gsr,temporalis': 0.8267716535433071,
#  'bno_gyro,bno_acc,bno_quat,masseter': 0.8335724533715926,
#  'bno_gyro,bno_acc,bno_quat,masseter,temporalis': 0.8377952755905512,
#  'bno_gyro,bno_acc,bno_quat,temporalis': 0.8448818897637795,
#  'bno_gyro,bno_acc,gsr': 0.8053562888570062,
#  'bno_gyro,bno_acc,gsr,masseter': 0.7991391678622669,
#  'bno_gyro,bno_acc,gsr,masseter,temporalis': 0.8110236220472441,
#  'bno_gyro,bno_acc,gsr,temporalis': 0.8259842519685039,
#  'bno_gyro,bno_acc,masseter': 0.7709230033476805,
#  'bno_gyro,bno_acc,masseter,temporalis': 0.8007874015748031,
#  'bno_gyro,bno_acc,temporalis': 0.7677165354330708,
#  'bno_gyro,bno_quat': 0.7977044476327116,
#  'bno_gyro,bno_quat,ble_acc': 0.8230511716881874,
#  'bno_gyro,bno_quat,ble_acc,gsr': 0.7986609277857485,
#  'bno_gyro,bno_quat,ble_acc,gsr,masseter': 0.8330942132950742,
#  'bno_gyro,bno_quat,ble_acc,gsr,masseter,temporalis': 0.8645669291338582,
#  'bno_gyro,bno_quat,ble_acc,gsr,temporalis': 0.8574803149606299,
#  'bno_gyro,bno_quat,ble_acc,masseter': 0.8254423720707795,
#  'bno_gyro,bno_quat,ble_acc,masseter,temporalis': 0.8480314960629921,
#  'bno_gyro,bno_quat,ble_acc,temporalis': 0.8409448818897638,
#  'bno_gyro,bno_quat,ble_gyro': 0.8072692491630798,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc': 0.8283118125298901,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,gsr': 0.8125298900047824,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,gsr,masseter': 0.8302247728359636,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.8409448818897638,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,gsr,temporalis': 0.8448818897637795,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,masseter': 0.8383548541367767,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,masseter,temporalis': 0.8503937007874016,
#  'bno_gyro,bno_quat,ble_gyro,ble_acc,temporalis': 0.8267716535433071,
#  'bno_gyro,bno_quat,ble_gyro,gsr': 0.8216164514586323,
#  'bno_gyro,bno_quat,ble_gyro,gsr,masseter': 0.8354854136776662,
#  'bno_gyro,bno_quat,ble_gyro,gsr,masseter,temporalis': 0.8614173228346457,
#  'bno_gyro,bno_quat,ble_gyro,gsr,temporalis': 0.8291338582677166,
#  'bno_gyro,bno_quat,ble_gyro,masseter': 0.8326159732185557,
#  'bno_gyro,bno_quat,ble_gyro,masseter,temporalis': 0.841732283464567,
#  'bno_gyro,bno_quat,ble_gyro,temporalis': 0.8330708661417323,
#  'bno_gyro,bno_quat,gsr': 0.8388330942132951,
#  'bno_gyro,bno_quat,gsr,masseter': 0.8321377331420373,
#  'bno_gyro,bno_quat,gsr,masseter,temporalis': 0.8440944881889764,
#  'bno_gyro,bno_quat,gsr,temporalis': 0.862992125984252,
#  'bno_gyro,bno_quat,masseter': 0.8249641319942611,
#  'bno_gyro,bno_quat,masseter,temporalis': 0.8385826771653543,
#  'bno_gyro,bno_quat,temporalis': 0.8551181102362204,
#  'bno_gyro,gsr': 0.7077953132472501,
#  'bno_gyro,gsr,masseter': 0.7187948350071736,
#  'bno_gyro,gsr,masseter,temporalis': 0.7511811023622047,
#  'bno_gyro,gsr,temporalis': 0.7307086614173228,
#  'bno_gyro,masseter': 0.6609277857484457,
#  'bno_gyro,masseter,temporalis': 0.6433070866141732,
#  'bno_gyro,temporalis': 0.6259842519685039,
#  'bno_quat': 0.8488761358201817,
#  'bno_quat,ble_acc': 0.8402678144428503,
#  'bno_quat,ble_acc,gsr': 0.8211382113821138,
#  'bno_quat,ble_acc,gsr,masseter': 0.8345289335246293,
#  'bno_quat,ble_acc,gsr,masseter,temporalis': 0.8307086614173228,
#  'bno_quat,ble_acc,gsr,temporalis': 0.8503937007874016,
#  'bno_quat,ble_acc,masseter': 0.8249641319942611,
#  'bno_quat,ble_acc,masseter,temporalis': 0.8433070866141732,
#  'bno_quat,ble_acc,temporalis': 0.8448818897637795,
#  'bno_quat,ble_gyro': 0.8082257293161167,
#  'bno_quat,ble_gyro,ble_acc': 0.8187470109995217,
#  'bno_quat,ble_gyro,ble_acc,gsr': 0.809660449545672,
#  'bno_quat,ble_gyro,ble_acc,gsr,masseter': 0.8249641319942611,
#  'bno_quat,ble_gyro,ble_acc,gsr,masseter,temporalis': 0.8330708661417323,
#  'bno_quat,ble_gyro,ble_acc,gsr,temporalis': 0.8511811023622047,
#  'bno_quat,ble_gyro,ble_acc,masseter': 0.8244858919177427,
#  'bno_quat,ble_gyro,ble_acc,masseter,temporalis': 0.8188976377952756,
#  'bno_quat,ble_gyro,ble_acc,temporalis': 0.8299212598425196,
#  'bno_quat,ble_gyro,gsr': 0.8220946915351507,
#  'bno_quat,ble_gyro,gsr,masseter': 0.8326159732185557,
#  'bno_quat,ble_gyro,gsr,masseter,temporalis': 0.8433070866141732,
#  'bno_quat,ble_gyro,gsr,temporalis': 0.8440944881889764,
#  'bno_quat,ble_gyro,masseter': 0.8220946915351507,
#  'bno_quat,ble_gyro,masseter,temporalis': 0.8496062992125984,
#  'bno_quat,ble_gyro,temporalis': 0.8330708661417323,
#  'bno_quat,gsr': 0.8474414155906265,
#  'bno_quat,gsr,masseter': 0.8101386896221904,
#  'bno_quat,gsr,masseter,temporalis': 0.8511811023622047,
#  'bno_quat,gsr,temporalis': 0.8393700787401575,
#  'bno_quat,masseter': 0.8091822094691535,
#  'bno_quat,masseter,temporalis': 0.8543307086614174,
#  'bno_quat,temporalis': 0.8354330708661417,
#  'gsr': 0.6456241032998565,
#  'gsr,masseter': 0.7010999521759923,
#  'gsr,masseter,temporalis': 0.7433070866141732,
#  'gsr,temporalis': 0.715748031496063,
#  'masseter': 0.6049736967957915,
#  'masseter,temporalis': 0.6393700787401575,
#  'temporalis': 0.6062992125984252}

# %%
for feature_set, data_and_labels in windows_with_labels__for_feature_set.items():
    X_train, X_test, y_train, y_test = train_test_split(data_and_labels["data"], data_and_labels["labels"], test_size=0.2)
    modelLR = LogisticRegression()
    modelLR.fit(X_train, y_train)
    lr_score__by_feature_set[feature_set] = modelDT.score(X_test, y_test)

lr_score__by_feature_set
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-cd00ae2c5cf2> in <module>()
#       3     modelLR = LogisticRegression()
#       4     modelLR.fit(X_train, y_train)
# ----> 5     lr_score__by_feature_set[feature_set] = modelDT.score(X_test, y_test)
#       6
#       7 lr_score__by_feature_set
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     649         from .metrics import accuracy_score
#     650
# --> 651         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     652
#     653     def _more_tags(self):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in predict(self, X, check_input)
#     465         """
#     466         check_is_fitted(self)
# --> 467         X = self._validate_X_predict(X, check_input)
#     468         proba = self.tree_.predict(X)
#     469         n_samples = X.shape[0]
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in _validate_X_predict(self, X, check_input)
#     431         """Validate the training data on predict (probabilities)."""
#     432         if check_input:
# --> 433             X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     434             if issparse(X) and (
#     435                 X.indices.dtype != np.intc or X.indptr.dtype != np.intc
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     583
#     584         if not no_val_X and check_params.get("ensure_2d", True):
# --> 585             self._check_n_features(X, reset=reset)
#     586
#     587         return out
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _check_n_features(self, X, reset)
#     399         if n_features != self.n_features_in_:
#     400             raise ValueError(
# --> 401                 f"X has {n_features} features, but {self.__class__.__name__} "
#     402                 f"is expecting {self.n_features_in_} features as input."
#     403             )
#
# ValueError: X has 192 features, but DecisionTreeClassifier is expecting 1184 features as input.

# %%
# x = knn_score__by_feature_set
# x = {k: v for k, v in sorted(x.items(), key=lambda item: item[1] + (8 - len(item[0].split(","))), reverse=True)}

# x

# %%
feature_set_bno_quat = windows_with_labels__for_feature_set["bno_quat"]

feature_set_bno_quat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2d329aae5d3b> in <module>()
# ----> 1 feature_set_bno_quat = windows_with_labels__for_feature_set["bno_quat"]
#       2
#       3 feature_set_bno_quat
#
# NameError: name 'windows_with_labels__for_feature_set' is not defined
